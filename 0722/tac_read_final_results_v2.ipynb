# %%
import pandas as pd
df = pd.read_csv('rolling_results_all_feature_2year_1year.csv')
df
# Out:
#     Unnamed: 0 Training_years Testing year  \
# 0            0      2012_2013       [2014]
# 1            1      2013_2014       [2015]
# 2            2      2014_2015       [2016]
# 3            3      2015_2016       [2017]
# 4            4      2016_2017       [2018]
# 5            5      2017_2018       [2019]
# 6            6      2018_2019       [2020]
# 7            7      2019_2020       [2021]
# 8            8      2020_2021       [2022]
# 9            9      2021_2022       [2023]
# 10          10      2022_2023       [2024]
#
#                                           Best Params  PR-AUC  Best threshold  \
# 0   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9501        0.465147
# 1   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9197        0.678842
# 2   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9476        0.577973
# 3   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9157        0.643234
# 4   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9651        0.567357
# 5   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9724        0.585305
# 6   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9789        0.511503
# 7   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9687        0.548162
# 8   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8890        0.752954
# 9   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9441        0.679562
# 10  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9860        0.522869
#
#     F1-score_test  Precision_test  Recall_test  F1 Gap (Train-Test)  \
# 0        0.908117        0.921031     0.895560             0.061341
# 1        0.899291        0.971538     0.837045             0.251232
# 2        0.917841        0.966588     0.873774             0.030201
# 3        0.888634        0.969517     0.820208             0.083148
# 4        0.902243        0.963378     0.848404             0.022265
# 5        0.934694        0.937794     0.931615            -0.036056
# 6        0.941712        0.945000     0.938446            -0.016463
# 7        0.942985        0.981652     0.907249             0.006321
# 8        0.817967        0.868005     0.773385             0.341546
# 9        0.908246        0.959267     0.862379             0.206903
# 10       0.962665        0.977268     0.948491            -0.016701
#
#     Train_size  Test_size
# 0       944555     519970
# 1      1041192     530021
# 2      1049991     524543
# 3      1054564     468913
# 4       993456     491374
# 5       960287     497246
# 6       988620     524057
# 7      1021303     509384
# 8      1033441     531485
# 9      1040869     512423
# 10     1043908     485872

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(8,6))
plt.plot(df['Testing year'], df['F1-score_test'], marker='o', label='f1-score')
plt.plot(df['Testing year'], df['Precision_test'], marker='o', label='Precision')
plt.plot(df['Testing year'], df['Recall_test'], marker='o', label='Recall')
plt.xlabel('Test year')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.legend()

plt.show()

# %%
df_feature = pd.read_csv('df_imp_0723.csv', index_col=0)
df_feature.index.name = 'Feature'

df_feature
# Out:
#                                          2014      2015      2016  \
# Feature
# co2_dry                              0.003122  0.017058  0.023112
# co2_wet                              0.004416  0.012792  0.017542
# co2_target_error                     0.001046  0.000463  0.000426
# co2_Cdrift                           0.004373  0.002189  0.001773
# co2_Nfiltered                        0.000565  0.000515  0.000288
# ...                                       ...       ...       ...
# co2_target_error_5min_zcore_res_gen  0.010223  0.000655  0.000206
# co2_target_error_per_rank_60s        0.003144  0.005767  0.002123
# co2_target_error_per_rank_5min       0.000997  0.006661  0.019915
# co2_Cdrift_per_rank_60s              0.000081  0.001513  0.002862
# co2_Cdrift_per_rank_5min             0.000183  0.003533  0.003610
#
#                                              2017      2018      2019  \
# Feature
# co2_dry                              1.285998e-02  0.005851  0.003645
# co2_wet                              1.711496e-03  0.003288  0.002568
# co2_target_error                     1.194921e-03  0.002461  0.004368
# co2_Cdrift                           3.692526e-03  0.001859  0.001025
# co2_Nfiltered                        3.179306e-03  0.002889  0.004333
# ...                                           ...       ...       ...
# co2_target_error_5min_zcore_res_gen  5.726950e-07  0.005126  0.003054
# co2_target_error_per_rank_60s        5.783950e-03  0.001828  0.000843
# co2_target_error_per_rank_5min       8.483261e-03  0.008442  0.007537
# co2_Cdrift_per_rank_60s              3.101186e-03  0.001572  0.003170
# co2_Cdrift_per_rank_5min             1.312574e-03  0.000158  0.000013
#
#                                          2020      2021      2022      2023  \
# Feature
# co2_dry                              0.001587  0.001627  0.001798  0.001384
# co2_wet                              0.001220  0.000637  0.001629  0.000536
# co2_target_error                     0.003388  0.004142  0.005307  0.001432
# co2_Cdrift                           0.001090  0.000506  0.001373  0.001388
# co2_Nfiltered                        0.004172  0.001507  0.001485  0.003973
# ...                                       ...       ...       ...       ...
# co2_target_error_5min_zcore_res_gen  0.001177  0.000427  0.002072  0.002267
# co2_target_error_per_rank_60s        0.000063  0.001514  0.002962  0.003340
# co2_target_error_per_rank_5min       0.010681  0.009108  0.010798  0.017891
# co2_Cdrift_per_rank_60s              0.001783  0.001814  0.001996  0.001944
# co2_Cdrift_per_rank_5min             0.003565  0.000141  0.000191  0.003275
#
#                                          2024
# Feature
# co2_dry                              0.000848
# co2_wet                              0.000675
# co2_target_error                     0.000683
# co2_Cdrift                           0.000427
# co2_Nfiltered                        0.001076
# ...                                       ...
# co2_target_error_5min_zcore_res_gen  0.000738
# co2_target_error_per_rank_60s        0.000184
# co2_target_error_per_rank_5min       0.006314
# co2_Cdrift_per_rank_60s              0.001056
# co2_Cdrift_per_rank_5min             0.000429
#
# [68 rows x 11 columns]

# %%
rank_df  = df_feature.rank(ascending=False, axis=0)

top10_counts =  (rank_df <=10).sum(axis=1).sort_values(ascending=False)

print("Top 10:",top10_counts)
# Out:
# Top 10: Feature
# time_since_switch                      11
# cycle_time_residual_60s                10
# cycle_time_diff_1                      10
# cycle_time_diff_2                      10
# cycle_time_roll_std_5min               10
#                                        ..
# co2_target_error_5min_zcore_res_gen     0
# co2_target_error_per_rank_60s           0
# co2_target_error_per_rank_5min          0
# co2_Cdrift_per_rank_60s                 0
# co2_Cdrift_per_rank_5min                0
# Length: 68, dtype: int64

# %%
import seaborn as sns

# %%
df = pd.read_csv('../data/processed/mhd_ch4_cnan_v1.csv')
df.to_parquet('../data/processed/mhd_ch4_cnan_v1.parquet')

# %%
plot_features = top10_counts[top10_counts>0].index
plt.figure(figsize=(12,8))
sns.heatmap(
    rank_df.loc[plot_features],
    annot=True,
)
plt.title('Heatmap of Training Feature Importances Across Rolling Windows')
# Out:
# <Axes: ylabel='Feature'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ======================================

# %%
df = pd.read_csv('final_paper_table_2_1.csv')
df = df[:-1]
df
# Out:
#     Unnamed: 0 Training_years Testing year  \
# 0            0      2012_2013       [2014]
# 1            1      2013_2014       [2015]
# 2            2      2014_2015       [2016]
# 3            3      2015_2016       [2017]
# 4            4      2016_2017       [2018]
# 5            5      2017_2018       [2019]
# 6            6      2018_2019       [2020]
# 7            7      2019_2020       [2021]
# 8            8      2020_2021       [2022]
# 9            9      2021_2022       [2023]
# 10          10      2022_2023       [2024]
# 11          11      2023_2024       [2025]
#
#                                           Best Params  PR-AUC  Best threshold  \
# 0   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9210        0.539047
# 1   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9055        0.721981
# 2   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9416        0.760674
# 3   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8960        0.734186
# 4   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9788        0.522528
# 5   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9669        0.702560
# 6   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9822        0.649835
# 7   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9685        0.628677
# 8   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8478        0.784301
# 9   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9032        0.711020
# 10  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9812        0.629802
# 11  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9863        0.639028
#
#     F1-score_test  Precision_test  Recall_test  F1 Gap (Train-Test)  \
# 0        0.879316        0.901197     0.858473             0.161330
# 1        0.906469        0.982150     0.841618             0.540715
# 2        0.905273        0.976071     0.844051             0.067889
# 3        0.844927        0.967242     0.750075             0.226587
# 4        0.932702        0.936309     0.929123            -0.018920
# 5        0.947730        0.968568     0.927770            -0.028149
# 6        0.956501        0.976626     0.937188            -0.011156
# 7        0.942429        0.978268     0.909124             0.008894
# 8        0.760691        0.700611     0.832042             0.435916
# 9        0.869680        0.869320     0.870041             0.170110
# 10       0.960942        0.996002     0.928266            -0.008713
# 11       0.965912        0.992551     0.940665            -0.000503
#
#     Train_size  Test_size Training_Year Test Year
# 0     944555.0   519970.0           NaN       NaN
# 1    1041192.0   530021.0           NaN       NaN
# 2    1049991.0   524543.0           NaN       NaN
# 3    1054564.0   468913.0           NaN       NaN
# 4     993456.0   491374.0           NaN       NaN
# 5     960287.0   497246.0           NaN       NaN
# 6     988620.0   524057.0           NaN       NaN
# 7    1021303.0   509384.0           NaN       NaN
# 8    1033441.0   531485.0           NaN       NaN
# 9    1040869.0   512423.0           NaN       NaN
# 10   1043908.0   485872.0           NaN       NaN
# 11    998295.0   289147.0           NaN       NaN

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(8,6))
plt.plot(df['Testing year'], df['F1-score_test'], marker='o', label='f1-score')
plt.plot(df['Testing year'], df['Precision_test'], marker='o', label='Precision')
plt.plot(df['Testing year'], df['Recall_test'], marker='o', label='Recall')
plt.xlabel('Test year')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.legend()
