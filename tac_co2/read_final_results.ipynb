# %%
import pandas as pd
df = pd.read_csv('final_paper_table.csv')

# %%
df = df[:-1]
df
# Out:
#     Unnamed: 0 Training_years Testing year  \
# 0            0      2012_2012       [2013]
# 1            1      2013_2013       [2014]
# 2            2      2014_2014       [2015]
# 3            3      2015_2015       [2016]
# 4            4      2016_2016       [2017]
# 5            5      2017_2017       [2018]
# 6            6      2018_2018       [2019]
# 7            7      2019_2019       [2020]
# 8            8      2020_2020       [2021]
# 9            9      2021_2021       [2022]
# 10          10      2022_2022       [2023]
# 11          11      2023_2023       [2024]
# 12          12      2024_2024       [2025]
#
#                                           Best Params  PR-AUC  Best threshold  \
# 0   {'clf__class_weight': 'balanced', 'clf__max_de...  0.6854        0.815861
# 1   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9374        0.603467
# 2   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8745        0.743869
# 3   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9289        0.677065
# 4   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8849        0.729022
# 5   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9782        0.494891
# 6   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9585        0.668258
# 7   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9855        0.557577
# 8   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9699        0.675185
# 9   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8205        0.869385
# 10  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9495        0.711657
# 11  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9852        0.615230
# 12  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9853        0.605496
#
#     F1-score_test  Precision_test  Recall_test  F1 Gap (Train-Test)  \
# 0        0.607545        0.863033     0.468772             0.494278
# 1        0.916347        0.942359     0.891732             0.082457
# 2        0.882109        0.976753     0.804186             0.566268
# 3        0.871220        0.863425     0.879158             0.093603
# 4        0.854352        0.937739     0.784584             0.355195
# 5        0.931499        0.919912     0.943382            -0.032434
# 6        0.924849        0.920027     0.929722             0.016681
# 7        0.957701        0.977230     0.938937            -0.009022
# 8        0.943962        0.978071     0.912152             0.023818
# 9        0.734467        0.734346     0.734589             0.372654
# 10       0.908469        0.958024     0.863789             0.086723
# 11       0.963387        0.986576     0.941264             0.002712
# 12       0.962912        0.990396     0.936912             0.010672
#
#     Train_size  Test_size Training_Year Test Year
# 0     423333.0   521222.0           NaN       NaN
# 1     521222.0   519970.0           NaN       NaN
# 2     519970.0   530021.0           NaN       NaN
# 3     530021.0   524543.0           NaN       NaN
# 4     524543.0   468913.0           NaN       NaN
# 5     468913.0   491374.0           NaN       NaN
# 6     491374.0   497246.0           NaN       NaN
# 7     497246.0   524057.0           NaN       NaN
# 8     524057.0   509384.0           NaN       NaN
# 9     509384.0   531485.0           NaN       NaN
# 10    531485.0   512423.0           NaN       NaN
# 11    512423.0   485872.0           NaN       NaN
# 12    485872.0   289147.0           NaN       NaN

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(8,6))
plt.plot(df['Testing year'], df['F1-score_test'], marker='o', label='f1-score')
plt.plot(df['Testing year'], df['Precision_test'], marker='o', label='Precision')
plt.plot(df['Testing year'], df['Recall_test'], marker='o', label='Recall')
plt.xlabel('Test year')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.legend()

plt.show()

# %%
df = pd.read_csv('final_paper_table_2_1.csv')
df = df[:-1]
df
# Out:
#     Unnamed: 0 Training_years Testing year  \
# 0            0      2012_2013       [2014]
# 1            1      2013_2014       [2015]
# 2            2      2014_2015       [2016]
# 3            3      2015_2016       [2017]
# 4            4      2016_2017       [2018]
# 5            5      2017_2018       [2019]
# 6            6      2018_2019       [2020]
# 7            7      2019_2020       [2021]
# 8            8      2020_2021       [2022]
# 9            9      2021_2022       [2023]
# 10          10      2022_2023       [2024]
# 11          11      2023_2024       [2025]
#
#                                           Best Params  PR-AUC  Best threshold  \
# 0   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9210        0.539047
# 1   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9055        0.721981
# 2   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9416        0.760674
# 3   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8960        0.734186
# 4   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9788        0.522528
# 5   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9669        0.702560
# 6   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9822        0.649835
# 7   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9685        0.628677
# 8   {'clf__class_weight': 'balanced', 'clf__max_de...  0.8478        0.784301
# 9   {'clf__class_weight': 'balanced', 'clf__max_de...  0.9032        0.711020
# 10  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9812        0.629802
# 11  {'clf__class_weight': 'balanced', 'clf__max_de...  0.9863        0.639028
#
#     F1-score_test  Precision_test  Recall_test  F1 Gap (Train-Test)  \
# 0        0.879316        0.901197     0.858473             0.161330
# 1        0.906469        0.982150     0.841618             0.540715
# 2        0.905273        0.976071     0.844051             0.067889
# 3        0.844927        0.967242     0.750075             0.226587
# 4        0.932702        0.936309     0.929123            -0.018920
# 5        0.947730        0.968568     0.927770            -0.028149
# 6        0.956501        0.976626     0.937188            -0.011156
# 7        0.942429        0.978268     0.909124             0.008894
# 8        0.760691        0.700611     0.832042             0.435916
# 9        0.869680        0.869320     0.870041             0.170110
# 10       0.960942        0.996002     0.928266            -0.008713
# 11       0.965912        0.992551     0.940665            -0.000503
#
#     Train_size  Test_size Training_Year Test Year
# 0     944555.0   519970.0           NaN       NaN
# 1    1041192.0   530021.0           NaN       NaN
# 2    1049991.0   524543.0           NaN       NaN
# 3    1054564.0   468913.0           NaN       NaN
# 4     993456.0   491374.0           NaN       NaN
# 5     960287.0   497246.0           NaN       NaN
# 6     988620.0   524057.0           NaN       NaN
# 7    1021303.0   509384.0           NaN       NaN
# 8    1033441.0   531485.0           NaN       NaN
# 9    1040869.0   512423.0           NaN       NaN
# 10   1043908.0   485872.0           NaN       NaN
# 11    998295.0   289147.0           NaN       NaN

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(8,6))
plt.plot(df['Testing year'], df['F1-score_test'], marker='o', label='f1-score')
plt.plot(df['Testing year'], df['Precision_test'], marker='o', label='Precision')
plt.plot(df['Testing year'], df['Recall_test'], marker='o', label='Recall')
plt.xlabel('Test year')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.legend()
