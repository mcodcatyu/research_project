# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import polars as pl
import time

# convert csv file into parquet file 
csv_filename = "../data/processed/tac_co2_formatted_v1.csv"
parquet_filename = "../data/processed/tac_co2_formatted_v1.parquet"

lazy_df = pl.scan_csv(csv_filename)
lazy_df.sink_parquet(parquet_filename)
