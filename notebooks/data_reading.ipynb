# %%
import pandas as pd

file_path = "../data/raw/mhd_ch4.txt"

df_mhd = pd.read_fwf(file_path) # skip first row, txt is space seperated

# %% [markdown]
# # Ignore this part
# import pandas as pd
# import io
#
# def clean_and_load(file_path, sep='\t'):
#     lines=[]
#     with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
#         for line in f:
#             cleaned_line = line.replace('\x00', '')
#             lines.append(cleaned_line)
#
#     joined_text = "".join(lines)
#     return pd.read_csv(io.StringIO(joined_text), sep=sep)
#
# file_path = "../data/raw/mhd_ch4.txt"
# df = clean_and_load(file_path)
# print(df.info())

# %%
df_mhd.head(20)
# Out:
#    Created: 19 May  26 12:50 GMT Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         -      - NaN         -          -          -          -      inlet
# 1      date   time NaN      type     sample   standard       port         ht
# 2    940216 142900 NaN       air        10m      G-024          3         10
# 3    940216 144900 NaN       air        10m      G-024          3         10
# 4    940216 150900 NaN       air        10m      G-024          3         10
# 5    940216 152900 NaN       air        10m      G-024          3         10
# 6    940216 180000 NaN       air        10m      G-024          3         10
# 7    940216 182000 NaN       air        10m      G-024          3         10
# 8    940216 184000 NaN       air        10m      G-024          3         10
# 9    940216 190000 NaN       air        10m      G-024          3         10
# 10   940216 192000 NaN       air        10m      G-024          3         10
# ...

# %%
df_mhd.iloc[[187]]
# Out:
#     Created: 19 May  26 12:50 GMT Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 187   940219 102700 NaN   cal1060      G-024      G-024          1          0
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 32 Unnamed: 33 Unnamed: 34  \
# 187      40.01      23.16        NaN  ...     1569.54     1695.49     1692.49
#
#     Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40  \
# 187       3.180         NaN    1692.489         NaN         NaN         NaN
#
#     Unnamed: 41
# 187         NaN
#
# [1 rows x 42 columns]

# %%
print(df_mhd.shape)
# Out:
# (817957, 42)

# %%
print(df_mhd.columns.tolist())
# Out:
# ['Created: 19 May', '26', '12:50 GMT', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41']

# %%
print(df_mhd.isnull().sum())
# Out:
# Created: 19 May         0
# 26                 817957
# 12:50 GMT               1
# Unnamed: 3              0
# Unnamed: 4              0
# Unnamed: 5              0
# Unnamed: 6              0
# Unnamed: 7         112284
# Unnamed: 8         112284
# Unnamed: 9         817955
# Unnamed: 10          2402
# Unnamed: 11          2329
# Unnamed: 12        817955
# Unnamed: 13          2404
# Unnamed: 14          1590
# Unnamed: 15          1590
# Unnamed: 16          1590
# Unnamed: 17          1590
# Unnamed: 18          1590
# Unnamed: 19          1590
# Unnamed: 20          1590
# Unnamed: 21          1590
# Unnamed: 22          1590
# Unnamed: 23         51247
# Unnamed: 24         49492
# Unnamed: 25         58674
# Unnamed: 26         51247
# Unnamed: 27         51247
# Unnamed: 28         51247
# Unnamed: 29         51247
# Unnamed: 30         49492
# Unnamed: 31         58674
# Unnamed: 32         52743
# Unnamed: 33         50993
# Unnamed: 34         59835
# ...

# %%
# feature rename

import pandas as pd
file_path = "../data/raw/mhd_ch4.txt"
df_mhd = pd.read_fwf(file_path) # skiprows =3 will cause value error, save feature columns and delete it later
df_mhd
# Out:
#        Created: 19 May  26 12:50 GMT Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             -      - NaN         -          -          -          -
# 1          date   time NaN      type     sample   standard       port
# 2        940216 142900 NaN       air        10m      G-024          3
# 3        940216 144900 NaN       air        10m      G-024          3
# 4        940216 150900 NaN       air        10m      G-024          3
# ...                ...  ..       ...        ...        ...        ...
# 817952   260518 065300 NaN       std      J-286      J-286          3
# 817953   260518 071300 NaN       air         9m      J-286          1
# 817954   260518 073300 NaN       std      J-286      J-286          3
# 817955   260518 075300 NaN       air         9m      J-286          1
# 817956   260518 081300 NaN       std      J-286      J-286          3
#
#        Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 32  \
# ...

# %%
feature_names = [  
'date', 'time', 'type', 'sample', 'standard', 'port', 'ht', 'tmod', 'tamb', 'temp', 'pflow', 'psamp', 'ploop', 'pamb', 'rt', 'w', 
'CH4_ht.1', 'CH4_area', 'CH4_skew', 'CH4_start_time', 'CH4_end_time', 'CH4_start_level', 'CH4_end_level', 'CH4_Rl_ht', 'CH4_Rl_a', 'CH4_Rl', 'CH4_norm_ht', 'CH4_norm_a', 'CH4_norm_w', 
'CH4_R_ht', 'CH4_R_a', 'CH4_R', 'CH4_C_ht', 'CH4_C_a', 'CH4_C', 'CH4_std_stdev', 'CH4_std_rep', 'CH4_Cstd', 'CH4_flag_ht', 'CH4_flag_a', 'CH4_flag', 'CH4_flag_p'
]
df_mhd.columns = feature_names

# %%
df_mhd.head(20)
# Out:
#              date  time  type  sample  standard  port     ht   tmod   tamb  \
# 0        -      -   NaN     -       -         -     -  inlet      -      -
# 1     date   time   NaN  type  sample  standard  port     ht   tmod   tamb
# 2   940216 142900   NaN   air     10m     G-024     3     10  40.00  32.27
# 3   940216 144900   NaN   air     10m     G-024     3     10  40.00  32.48
# 4   940216 150900   NaN   air     10m     G-024     3     10  40.01  32.75
# 5   940216 152900   NaN   air     10m     G-024     3     10  40.00  32.92
# 6   940216 180000   NaN   air     10m     G-024     3     10  40.00  33.31
# 7   940216 182000   NaN   air     10m     G-024     3     10  40.01  33.10
# 8   940216 184000   NaN   air     10m     G-024     3     10  40.01  33.20
# 9   940216 190000   NaN   air     10m     G-024     3     10  40.00  33.39
# 10  940216 192000   NaN   air     10m     G-024     3     10  40.00  33.61
# ...

# %%
df_mhd = df_mhd.drop(index=[0,1]).reset_index(drop=True)
df_mhd
# Out:
#                  date  time type sample standard port  ht   tmod   tamb temp  \
# 0       940216 142900   NaN  air    10m    G-024    3  10  40.00  32.27  NaN
# 1       940216 144900   NaN  air    10m    G-024    3  10  40.00  32.48  NaN
# 2       940216 150900   NaN  air    10m    G-024    3  10  40.01  32.75  NaN
# 3       940216 152900   NaN  air    10m    G-024    3  10  40.00  32.92  NaN
# 4       940216 180000   NaN  air    10m    G-024    3  10  40.00  33.31  NaN
# ...               ...   ...  ...    ...      ...  ...  ..    ...    ...  ...
# 817950  260518 065300   NaN  std  J-286    J-286    3   0  40.00  22.06  NaN
# 817951  260518 071300   NaN  air     9m    J-286    1   9  40.00  22.32  NaN
# 817952  260518 073300   NaN  std  J-286    J-286    3   0  40.00  22.19  NaN
# 817953  260518 075300   NaN  air     9m    J-286    1   9  40.00  22.10  NaN
# 817954  260518 081300   NaN  std  J-286    J-286    3   0  40.00  22.23  NaN
#
# ...

# %%
df_mhd['time'].to_string
df_mhd['time'].isnull().sum()
# Out:
# np.int64(817955)

# %%
df_mhd['date'] = df_mhd['date'].astype(str)

df_mhd['time'] = df_mhd['date'].str[6:]
df_mhd['date'] = df_mhd['date'].str[:6]

# %%
df_mhd.head(20)
# Out:
#       date     time type sample standard port  ht   tmod   tamb temp  ...  \
# 0   940216   142900  air    10m    G-024    3  10  40.00  32.27  NaN  ...
# 1   940216   144900  air    10m    G-024    3  10  40.00  32.48  NaN  ...
# 2   940216   150900  air    10m    G-024    3  10  40.01  32.75  NaN  ...
# 3   940216   152900  air    10m    G-024    3  10  40.00  32.92  NaN  ...
# 4   940216   180000  air    10m    G-024    3  10  40.00  33.31  NaN  ...
# 5   940216   182000  air    10m    G-024    3  10  40.01  33.10  NaN  ...
# 6   940216   184000  air    10m    G-024    3  10  40.01  33.20  NaN  ...
# 7   940216   190000  air    10m    G-024    3  10  40.00  33.39  NaN  ...
# 8   940216   192000  air    10m    G-024    3  10  40.00  33.61  NaN  ...
# 9   940216   194000  air    10m    G-024    3  10  40.01  33.66  NaN  ...
# 10  940216   202300  air    10m    G-024    3  10  40.00  33.17  NaN  ...
# 11  940216   204300  air    10m    G-024    3  10  40.00  33.05  NaN  ...
# ...

# %%
df_mhd.iloc[[185]]
# Out:
#        date     time     type sample standard port ht   tmod   tamb temp  ...  \
# 185  940219   102700  cal1060  G-024    G-024    1  0  40.01  23.16  NaN  ...
#
#     CH4_C_ht  CH4_C_a    CH4_C CH4_std_stdev CH4_std_rep  CH4_Cstd  \
# 185  1569.54  1695.49  1692.49         3.180         NaN  1692.489
#
#     CH4_flag_ht CH4_flag_a CH4_flag CH4_flag_p
# 185         NaN        NaN      NaN        NaN
#
# [1 rows x 42 columns]

# %%
df_mhd.to_csv("../data/processed/mhd_ch4_formatted_v1.csv", index=False)

# %% [markdown]
# READ tac_ch4.txt

# %%
import pandas as pd

file_path = "../data/raw/tac_ch4.txt"

df_tac = pd.read_csv(file_path, skiprows=1, sep=r'\s+', header=1) # skip first row, txt is space seperated

# %%
df_tac
# Out:
#            date    time     type sample      standard  port       dry  \
# 0        120111  162730  unknown      -  USN-20112109     0  1944.517
# 1        120111  162830  unknown      -  USN-20112109     0  1972.043
# 2        120111  162930  unknown      -  USN-20112109     0  1940.176
# 3        120111  163030  unknown      -  USN-20112109     0  2021.915
# 4        120111  163130  unknown      -  USN-20112109     0  1976.217
# ...         ...     ...      ...    ...           ...   ...       ...
# 6828985  250722   70630      air   185m       CFF-011    10  2057.675
# 6828986  250722   70730      air   185m       CFF-011    10  2061.071
# 6828987  250722   70830      air   185m       CFF-011    10  2064.147
# 6828988  250722   70930      air   185m       CFF-011    10  2060.348
# 6828989  250722   71030      air   185m       CFF-011    10  2059.633
#
#               wet   stdev  std_rep  ...      h2o  stdev.1      press  \
# ...

# %%
print(df_tac.columns.tolist())
# Out:
# ['date', 'time', 'type', 'sample', 'standard', 'port', 'dry', 'wet', 'stdev', 'std_rep', 'std_stdev', 'target_error', 'Cdrift', 'C', 'N', 'Nfiltered', 'time.1', 'h2o', 'stdev.1', 'press', 'press_stdev', 'temp', 'temp_stdev', 'temp.1', 'temp.2', 'temp.3', 'valve']

# %%
df_tac.shape
# Out:
# (6828990, 27)

# %% [markdown]
# deal the problem that flag sign is connected with featurre C (such as 1827x)

# %%
df_tac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6828990 entries, 0 to 6828989
# Data columns (total 27 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          int64
#  1   time          int64
#  2   type          object
#  3   sample        object
#  4   standard      object
#  5   port          int64
#  6   dry           float64
#  7   wet           float64
#  8   stdev         float64
#  9   std_rep       float64
#  10  std_stdev     float64
#  11  target_error  float64
#  12  Cdrift        float64
#  13  C             object
#  14  N             int64
#  15  Nfiltered     float64
#  16  time.1        float64
#  17  h2o           float64
#  18  stdev.1       float64
#  19  press         float64
#  20  press_stdev   float64
#  21  temp          float64
#  22  temp_stdev    float64
#  23  temp.1        float64
#  24  temp.2        float64
#  25  temp.3        float64
#  26  valve         float64
# dtypes: float64(19), int64(4), object(4)
# ...

# %% [markdown]
# C should be flaot?
# convert into float first

# %%
df_tac['C'].head(20)
# Out:
# 0     1955.527x
# 1     1983.217x
# 2     1951.159x
# 3     2033.386x
# 4     1987.416x
# 5     1988.226F
# 6     1985.406F
# 7     1915.031F
# 8     1940.282F
# 9     1981.204F
# 10    1931.891F
# 11    1980.398F
# 12    1947.380F
# 13    1949.511F
# 14    1909.053F
# 15    1939.482F
# 16    1913.494F
# 17    1949.543F
# 18    1934.023F
# 19    1895.129F
# Name: C, dtype: object

# %%
import numpy as np

def split_flag (val):
    if pd.isna(val):
        return np.nan, np.nan
    
    val_str = str(val).strip()
    # check if last val is a character(Flag)
    if val_str[-1].isalpha() or val_str[-1] == '*':
        c_val = float(val_str[:-1])
        flag_val = val_str[-1]
    else:
        c_val = float(val_str) # normal value, then direcly convert to float
        flag_val = " " # no flag, give it a space
    
    return c_val, flag_val

# %%
df_tac['C'], df_tac['CH4_flag'] = zip(*df_tac['C'].map(split_flag))

print(df_tac[['C', 'CH4_flag']].head(20))
df_tac['C']
# Out:
#            C CH4_flag
# 0   1955.527        x
# 1   1983.217        x
# 2   1951.159        x
# 3   2033.386        x
# 4   1987.416        x
# 5   1988.226        F
# 6   1985.406        F
# 7   1915.031        F
# 8   1940.282        F
# 9   1981.204        F
# 10  1931.891        F
# 11  1980.398        F
# 12  1947.380        F
# 13  1949.511        F
# 14  1909.053        F
# 15  1939.482        F
# 16  1913.494        F
# 17  1949.543        F
# 18  1934.023        F
# 19  1895.129        F
# 0          1955.527
# 1          1983.217
# 2          1951.159
# 3          2033.386
# 4          1987.416
#              ...
# 6828985    2059.287
# 6828986    2062.687
# 6828987    2065.768
# 6828988    2061.963
# 6828989    2061.248
# Name: C, Length: 6828990, dtype: float64

# %%
df_tac.head(20)
# Out:
#       date    time     type sample      standard  port       dry       wet  \
# 0   120111  162730  unknown      -  USN-20112109     0  1944.517  1945.109
# 1   120111  162830  unknown      -  USN-20112109     0  1972.043  1972.643
# 2   120111  162930  unknown      -  USN-20112109     0  1940.176  1940.768
# 3   120111  163030  unknown      -  USN-20112109     0  2021.915  2022.526
# 4   120111  163130  unknown      -  USN-20112109     0  1976.217  1976.825
# 5   120111  163230  unknown      -  USN-20112109     0  1977.023  1977.629
# 6   120111  163330  unknown      -  USN-20112109     0  1974.220  1974.855
# 7   120111  163430  unknown      -  USN-20112109     0  1904.261  1904.902
# 8   120111  163530  unknown      -  USN-20112109     0  1929.363  1930.012
# 9   120111  163630  unknown      -  USN-20112109     0  1970.042  1970.705
# 10  120111  163730  unknown      -  USN-20112109     0  1921.022  1921.668
# ...

# %%
df_tac.to_csv("../data/processed/tac_ch4_formatted_v1.csv", index=False)

# %%
import pandas as pd

file_path = "../data/raw/tac_co2.txt"

df_taco2 = pd.read_csv(file_path, skiprows=1, sep=r'\s+', header=1) # skip first row, txt is space seperated

# %%
df_taco2.head(20)
# Out:
#       date    time     type sample      standard  port      dry      wet  \
# 0   120111  162730  unknown      -  USN-20112109     0  403.464  403.606
# 1   120111  162830  unknown      -  USN-20112109     0  402.944  403.085
# 2   120111  162930  unknown      -  USN-20112109     0  400.992  401.133
# 3   120111  163030  unknown      -  USN-20112109     0  401.753  401.893
# 4   120111  163130  unknown      -  USN-20112109     0  401.479  401.622
# 5   120111  163230  unknown      -  USN-20112109     0  401.215  401.356
# 6   120111  163330  unknown      -  USN-20112109     0  401.416  401.565
# 7   120111  163430  unknown      -  USN-20112109     0  404.622  404.779
# 8   120111  163530  unknown      -  USN-20112109     0  401.350  401.506
# 9   120111  163630  unknown      -  USN-20112109     0  410.890  411.049
# 10  120111  163730  unknown      -  USN-20112109     0  402.361  402.517
# 11  120111  163830  unknown      -  USN-20112109     0  401.677  401.833
# ...

# %%
df_taco2['C']
# Out:
# 0          406.300x
# 1          405.776x
# 2          403.811x
# 3          404.577x
# 4          404.301x
#              ...
# 6828985     437.131
# 6828986     438.124
# 6828987     438.832
# 6828988     437.999
# 6828989     437.717
# Name: C, Length: 6828990, dtype: object

# %%
df_taco2['C'], df_taco2['CH4_flag'] = zip(*df_taco2['C'].map(split_flag))

print(df_taco2[['C', 'CH4_flag']].head(20))
df_tac['C']
# Out:
#           C CH4_flag
# 0   406.300        x
# 1   405.776        x
# 2   403.811        x
# 3   404.577        x
# 4   404.301        x
# 5   404.035        F
# 6   404.238        F
# 7   407.466        F
# 8   404.171        F
# 9   413.777        F
# 10  405.189        F
# 11  404.500        F
# 12  404.433        F
# 13  405.599        F
# 14  403.956        F
# 15  405.506        F
# 16  403.097        F
# 17  405.365        F
# 18  405.538        F
# 19  403.039        F
# 0          1955.527
# 1          1983.217
# 2          1951.159
# 3          2033.386
# 4          1987.416
#              ...
# 6828985    2059.287
# 6828986    2062.687
# 6828987    2065.768
# 6828988    2061.963
# 6828989    2061.248
# Name: C, Length: 6828990, dtype: float64

# %%
df_taco2.head(20)
# Out:
#       date    time     type sample      standard  port      dry      wet  \
# 0   120111  162730  unknown      -  USN-20112109     0  403.464  403.606
# 1   120111  162830  unknown      -  USN-20112109     0  402.944  403.085
# 2   120111  162930  unknown      -  USN-20112109     0  400.992  401.133
# 3   120111  163030  unknown      -  USN-20112109     0  401.753  401.893
# 4   120111  163130  unknown      -  USN-20112109     0  401.479  401.622
# 5   120111  163230  unknown      -  USN-20112109     0  401.215  401.356
# 6   120111  163330  unknown      -  USN-20112109     0  401.416  401.565
# 7   120111  163430  unknown      -  USN-20112109     0  404.622  404.779
# 8   120111  163530  unknown      -  USN-20112109     0  401.350  401.506
# 9   120111  163630  unknown      -  USN-20112109     0  410.890  411.049
# 10  120111  163730  unknown      -  USN-20112109     0  402.361  402.517
# 11  120111  163830  unknown      -  USN-20112109     0  401.677  401.833
# ...

# %%
df_taco2.to_csv("../data/processed/tac_co2_formatted_v1.csv", index=False)
