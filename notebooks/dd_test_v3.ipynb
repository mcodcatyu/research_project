# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style='darkgrid')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
raw_data = pd.read_csv('../data/processed/mhd_ch4_ml_v2.csv')
raw_data.head(5)
# Out:
# /tmp/ipykernel_1245/669193869.py:1: DtypeWarning: Columns (37) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv('../data/processed/mhd_ch4_ml_v2.csv')
#      date    time type sample standard  port    ht   tmod   tamb  lab_temp  \
# 0  940216  142900  air    10m    G-024     3  10.0  40.00  32.27       NaN
# 1  940216  144900  air    10m    G-024     3  10.0  40.00  32.48       NaN
# 2  940216  150900  air    10m    G-024     3  10.0  40.01  32.75       NaN
# 3  940216  152900  air    10m    G-024     3  10.0  40.00  32.92       NaN
# 4  940216  180000  air    10m    G-024     3  10.0  40.00  33.31       NaN
#
#    pflow   psamp  ploop   pamb  CH4_rt  CH4_w    CH4_ht   CH4_area  CH4_skew  \
# 0  841.9  761.10    NaN  761.1     0.0   0.00       0.0        0.0      0.00
# 1  840.4  761.07    NaN  761.2     0.0   0.00       0.0        0.0      0.00
# 2  839.4  760.99    NaN  760.9   109.8   2.60  190908.0   496440.0      0.63
# 3  839.6  760.96    NaN  760.9    94.8   6.85  151667.0  1065982.0      1.02
# 4  845.4  760.72    NaN  760.6     0.0   0.00       0.0        0.0      0.00
#
#    CH4_start_time  CH4_end_time  CH4_start_level  CH4_end_level  CH4_Rl_ht  \
# 0             0.0           0.0              0.0            0.0        NaN
# 1             0.0           0.0              0.0            0.0        NaN
# 2           102.0         135.4          10063.0        10029.0        NaN
# 3            86.2         129.0          99999.0        99999.0        NaN
# 4             0.0           0.0              0.0            0.0        NaN
#
#    CH4_Rl_a  CH4_Rl  CH4_norm_ht  CH4_norm_a  CH4_norm_w  CH4_R_ht  CH4_R_a  \
# 0       NaN     NaN          NaN         NaN         NaN       NaN      NaN
# 1       NaN     NaN          NaN         NaN         NaN       NaN      NaN
# 2       NaN     NaN          NaN         NaN         NaN       NaN      NaN
# 3       NaN     NaN          NaN         NaN         NaN       NaN      NaN
# 4       NaN     NaN          NaN         NaN         NaN       NaN      NaN
#
#    CH4_R  CH4_C_ht  CH4_C_a  CH4_C  CH4_std_stdev  CH4_std_rep  CH4_Cstd  \
# 0    NaN       NaN      NaN    NaN            NaN          NaN  1692.489
# 1    NaN       NaN      NaN    NaN            NaN          NaN  1692.489
# 2    NaN       NaN      NaN    NaN            NaN          NaN  1692.489
# 3    NaN       NaN      NaN    NaN            NaN          NaN  1692.489
# 4    NaN       NaN      NaN    NaN            NaN          NaN  1692.489
#
#   CH4_flag_ht CH4_flag_a CH4_flag CH4_flag_p  CH4_flag_ht_bin  CH4_flag_a_bin  \
# 0           F          F                                    1               1
# 1           F          F                                    1               1
# 2           F          F                                    1               1
# 3                                                           0               0
# 4           F          F                                    1               1
#
#    label1  datetime_str             datetime  is_ht_999  is_area_999  \
# 0       1  940216142900  1994-02-16 14:29:00      False        False
# 1       1  940216144900  1994-02-16 14:49:00      False        False
# 2       1  940216150900  1994-02-16 15:09:00      False        False
# 3       0  940216152900  1994-02-16 15:29:00      False        False
# 4       1  940216180000  1994-02-16 18:00:00      False        False
#
#    is_rt_zero  is_w_zero  duration  is_duration_spike  baseline_drift  \
# 0        True       True       0.0              False             0.0
# 1        True       True       0.0              False             0.0
# 2       False      False      33.4              False           -34.0
# 3       False      False      42.8              False             0.0
# 4        True       True       0.0              False             0.0
#
#    ht_area_ratio last_std_time  seconds_since_last_std  type_std  type_air  \
# 0            NaN           NaN                     NaN         0         1
# 1            NaN           NaN                     NaN         0         1
# 2       0.384554           NaN                     NaN         0         1
# 3       0.142279           NaN                     NaN         0         1
# 4            NaN           NaN                     NaN         0         1
#
#    type_tank  type_blank  type_cal  type_other last_cal_time  \
# 0          0           0         0           0           NaN
# 1          0           0         0           0           NaN
# 2          0           0         0           0           NaN
# 3          0           0         0           0           NaN
# 4          0           0         0           0           NaN
#
#    seconds_since_last_cal  year  month  day  hour  minute  seconds  \
# 0                     NaN  1994      2   16    14      29        0
# 1                     NaN  1994      2   16    14      49        0
# 2                     NaN  1994      2   16    15       9        0
# 3                     NaN  1994      2   16    15      29        0
# 4                     NaN  1994      2   16    18       0        0
#
#    psamp_roll_mean_10  pamb_roll_mean_10  pflow_roll_mean_10  \
# 0                 NaN                NaN                 NaN
# 1          761.100000         761.100000          841.900000
# 2          761.085000         761.150000          841.150000
# 3          761.053333         761.066667          840.566667
# 4          761.030000         761.025000          840.325000
#
#    tmod_roll_mean_10  psamp_roll_mean_100  pamb_roll_mean_100  \
# 0                NaN                  NaN                 NaN
# 1          40.000000           761.100000          761.100000
# 2          40.000000           761.085000          761.150000
# 3          40.003333           761.053333          761.066667
# 4          40.002500           761.030000          761.025000
#
#    pflow_roll_mean_100  tmod_roll_mean_100  psamp_roll_std_10  \
# 0                  NaN                 NaN                NaN
# 1           841.900000           40.000000                NaN
# 2           841.150000           40.000000           0.021213
# 3           840.566667           40.003333           0.056862
# 4           840.325000           40.002500           0.065828
#
#    pamb_roll_std_10  pflow_roll_std_10  CH4_rt_roll_std_10  \
# 0               NaN                NaN                 NaN
# 1               NaN                NaN                 NaN
# 2          0.070711           1.060660            0.000000
# 3          0.152753           1.258306           63.393060
# 4          0.150000           1.135415           59.379542
#
#    psamp_roll_std_100  pamb_roll_std_100  pflow_roll_std_100  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2            0.021213           0.070711            1.060660
# 3            0.056862           0.152753            1.258306
# 4            0.065828           0.150000            1.135415
#
#    CH4_rt_roll_std_100  psamp_diff_1  pflow_diff_1  CH4_area_diff_1  \
# 0                  NaN           NaN           NaN              NaN
# 1                  NaN           NaN           NaN              NaN
# 2             0.000000         -0.03          -1.5              0.0
# 3            63.393060         -0.08          -1.0         496440.0
# 4            59.379542         -0.03           0.2         569542.0
#
#    psamp_lag_1  pflow_lag_1
# 0          NaN          NaN
# 1       761.10        841.9
# 2       761.07        840.4
# 3       760.99        839.4
# 4       760.96        839.6

# %%
raw_data.columns
# Out:
# Index(['date', 'time', 'type', 'sample', 'standard', 'port', 'ht', 'tmod',
#        'tamb', 'lab_temp', 'pflow', 'psamp', 'ploop', 'pamb', 'CH4_rt',
#        'CH4_w', 'CH4_ht', 'CH4_area', 'CH4_skew', 'CH4_start_time',
#        'CH4_end_time', 'CH4_start_level', 'CH4_end_level', 'CH4_Rl_ht',
#        'CH4_Rl_a', 'CH4_Rl', 'CH4_norm_ht', 'CH4_norm_a', 'CH4_norm_w',
#        'CH4_R_ht', 'CH4_R_a', 'CH4_R', 'CH4_C_ht', 'CH4_C_a', 'CH4_C',
#        'CH4_std_stdev', 'CH4_std_rep', 'CH4_Cstd', 'CH4_flag_ht', 'CH4_flag_a',
#        'CH4_flag', 'CH4_flag_p', 'CH4_flag_ht_bin', 'CH4_flag_a_bin', 'label1',
#        'datetime_str', 'datetime', 'is_ht_999', 'is_area_999', 'is_rt_zero',
#        'is_w_zero', 'duration', 'is_duration_spike', 'baseline_drift',
#        'ht_area_ratio', 'last_std_time', 'seconds_since_last_std', 'type_std',
#        'type_air', 'type_tank', 'type_blank', 'type_cal', 'type_other',
#        'last_cal_time', 'seconds_since_last_cal', 'year', 'month', 'day',
#        'hour', 'minute', 'seconds', 'psamp_roll_mean_10', 'pamb_roll_mean_10',
#        'pflow_roll_mean_10', 'tmod_roll_mean_10', 'psamp_roll_mean_100',
#        'pamb_roll_mean_100', 'pflow_roll_mean_100', 'tmod_roll_mean_100',
#        'psamp_roll_std_10', 'pamb_roll_std_10', 'pflow_roll_std_10',
#        'CH4_rt_roll_std_10', 'psamp_roll_std_100', 'pamb_roll_std_100',
#        'pflow_roll_std_100', 'CH4_rt_roll_std_100', 'psamp_diff_1',
#        'pflow_diff_1', 'CH4_area_diff_1', 'psamp_lag_1', 'pflow_lag_1'],
#       dtype='object')

# %%
data = raw_data.copy()
data = data.drop(data[data['year']==2026].index)
data.tail()
# Out:
#           date    time type sample standard  port   ht  tmod   tamb  lab_temp  \
# 808206  251231  223800  std  J-286    J-286     3  0.0  40.0  21.01       NaN
# 808207  251231  225800  air     9m    J-286     1  9.0  40.0  20.74       NaN
# 808208  251231  231800  std  J-286    J-286     3  0.0  40.0  20.88       NaN
# 808209  251231  233800  air     9m    J-286     1  9.0  40.0  20.79       NaN
# 808210  251231  235800  std  J-286    J-286     3  0.0   NaN    NaN       NaN
#
#         pflow   psamp  ploop   pamb  CH4_rt  CH4_w    CH4_ht   CH4_area  \
# 808206  817.8  765.45    NaN  765.7    94.0   7.83  170066.0  1489856.0
# 808207  813.2  765.28    NaN  765.2    94.0   7.85  171821.0  1508117.0
# 808208  817.5  765.08    NaN  764.9    94.2   7.84  169569.0  1487622.0
# 808209  813.3  765.05    NaN  765.0    94.2   7.86  170281.0  1496142.0
# 808210  817.4  764.90    NaN    NaN    94.2   7.83  169985.0  1489453.0
#
#         CH4_skew  CH4_start_time  CH4_end_time  CH4_start_level  \
# 808206      1.16            80.8         133.4          23823.0
# 808207      1.16            80.8         133.4          23750.0
# 808208      1.06            80.8         133.6          23740.0
# 808209      1.07            80.8         133.6          23756.0
# 808210      1.09            80.8         133.4          23691.0
#
#         CH4_end_level  CH4_Rl_ht  CH4_Rl_a   CH4_Rl  CH4_norm_ht  CH4_norm_a  \
# 808206        24073.0    1.00099   1.00067  1.00067       1.0010      1.0007
# 808207        24058.0    1.01178   1.01300  1.01300       1.0118      1.0130
# 808208        24030.0    0.99744   0.99876  0.99876       0.9973      0.9986
# 808209        24015.0    1.00289   1.00503  1.00503       1.0030      1.0051
# 808210        24015.0        NaN       NaN      NaN          NaN         NaN
#
#         CH4_norm_w  CH4_R_ht  CH4_R_a    CH4_R  CH4_C_ht  CH4_C_a    CH4_C  \
# 808206      0.9997   1.00099  1.00067  1.00067   2017.92  2017.27  2017.27
# 808207      1.0014   1.01178  1.01300  1.01300   2039.67  2042.12  2042.12
# 808208      1.0015   0.99744  0.99876  0.99876   2010.76  2013.42  2013.42
# 808209      1.0021   1.00289  1.00503  1.00503   2021.75  2026.06  2026.06
# 808210         NaN       NaN      NaN      NaN       NaN      NaN      NaN
#
#         CH4_std_stdev  CH4_std_rep  CH4_Cstd CH4_flag_ht CH4_flag_a CH4_flag  \
# 808206          2.406          NaN  2015.923                               A
# 808207          2.396        2.427  2015.923                               A
# 808208          2.413          NaN  2015.923                               A
# 808209          2.401        2.413  2015.923                               A
# 808210          2.415          NaN  2015.923                               A
#
#        CH4_flag_p  CH4_flag_ht_bin  CH4_flag_a_bin  label1  datetime_str  \
# 808206                           0               0       0  251231223800
# 808207                           0               0       0  251231225800
# 808208                           0               0       0  251231231800
# 808209                           0               0       0  251231233800
# 808210                           0               0       0  251231235800
#
#                    datetime  is_ht_999  is_area_999  is_rt_zero  is_w_zero  \
# 808206  2025-12-31 22:38:00      False        False       False      False
# 808207  2025-12-31 22:58:00      False        False       False      False
# 808208  2025-12-31 23:18:00      False        False       False      False
# 808209  2025-12-31 23:38:00      False        False       False      False
# 808210  2025-12-31 23:58:00      False        False       False      False
#
#         duration  is_duration_spike  baseline_drift  ht_area_ratio  \
# 808206      52.6              False           250.0       0.114149
# 808207      52.6              False           308.0       0.113931
# 808208      52.8              False           290.0       0.113987
# 808209      52.8              False           259.0       0.113813
# 808210      52.6              False           324.0       0.114126
#
#               last_std_time  seconds_since_last_std  type_std  type_air  \
# 808206  2025-12-31 21:57:00                  2460.0         1         0
# 808207  2025-12-31 21:57:00                  3660.0         0         1
# 808208  2025-12-31 22:38:00                  2400.0         1         0
# 808209  2025-12-31 22:38:00                  3600.0         0         1
# 808210  2025-12-31 23:18:00                  2400.0         1         0
#
#         type_tank  type_blank  type_cal  type_other        last_cal_time  \
# 808206          0           0         0           0  2025-12-28 06:16:00
# 808207          0           0         0           0  2025-12-28 06:16:00
# 808208          0           0         0           0  2025-12-28 06:16:00
# 808209          0           0         0           0  2025-12-28 06:16:00
# 808210          0           0         0           0  2025-12-28 06:16:00
#
#         seconds_since_last_cal  year  month  day  hour  minute  seconds  \
# 808206                318120.0  2025     12   31    22      38        0
# 808207                319320.0  2025     12   31    22      58        0
# 808208                320520.0  2025     12   31    23      18        0
# 808209                321720.0  2025     12   31    23      38        0
# 808210                322920.0  2025     12   31    23      58        0
#
#         psamp_roll_mean_10  pamb_roll_mean_10  pflow_roll_mean_10  \
# 808206             766.407             766.33              816.44
# 808207             766.222             766.18              816.24
# 808208             766.039             766.00              816.19
# 808209             765.872             765.82              816.02
# 808210             765.710             765.66              815.82
#
#         tmod_roll_mean_10  psamp_roll_mean_100  pamb_roll_mean_100  \
# 808206               40.0             772.0808             772.056
# 808207               40.0             771.9890             771.966
# 808208               40.0             771.8964             771.871
# 808209               40.0             771.8028             771.775
# 808210               40.0             771.7077             771.680
#
#         pflow_roll_mean_100  tmod_roll_mean_100  psamp_roll_std_10  \
# 808206              822.436                40.0           0.583306
# 808207              822.381                40.0           0.561581
# 808208              822.240                40.0           0.537720
# 808209              822.179                40.0           0.551519
# 808210              822.040                40.0           0.528520
#
#         pamb_roll_std_10  pflow_roll_std_10  CH4_rt_roll_std_10  \
# 808206          0.586989           2.761320             0.10328
# 808207          0.528730           2.555691             0.10328
# 808208          0.524934           2.615106             0.10328
# 808209          0.565292           2.447584             0.10328
# 808210          0.546097           2.590495             0.10328
#
#         psamp_roll_std_100  pamb_roll_std_100  pflow_roll_std_100  \
# 808206            2.832881           2.881439            3.691583
# 808207            2.897443           2.938020            3.719446
# 808208            2.962336           3.001626            3.797527
# 808209            3.028294           3.069445            3.824358
# 808210            3.089538           3.130656            3.892028
#
#         CH4_rt_roll_std_100  psamp_diff_1  pflow_diff_1  CH4_area_diff_1  \
# 808206             0.094516         -0.47          -4.6          34189.0
# 808207             0.095219          0.08           4.1         -34481.0
# 808208             0.095874         -0.17          -4.6          18261.0
# 808209             0.095874         -0.20           4.3         -20495.0
# 808210             0.095874         -0.03          -4.2           8520.0
#
#         psamp_lag_1  pflow_lag_1
# 808206       765.37        813.7
# 808207       765.45        817.8
# 808208       765.28        813.2
# 808209       765.08        817.5
# 808210       765.05        813.3

# %%
feature_cols = [
    #'sample'	,'standard',	
    #'port'	,'ht',
    'tmod'	,'tamb',
    'pflow', 'psamp',
    'pamb'	,
    'CH4_rt',	'CH4_w',	'CH4_ht'	,
    'CH4_area',	'CH4_skew'	,
    'CH4_start_time',	'CH4_end_time'	,'CH4_start_level',	'CH4_end_level',
    #'CH4_Rl_ht',	'CH4_Rl_a',	'CH4_Rl',	
    #'CH4_norm_ht','CH4_norm_a',	'CH4_norm_w',
    #'CH4_R_ht','CH4_R_a', 'CH4_R'	,'
    #'CH4_C_ht'	,'CH4_C_a',	'CH4_C',	
    # std
    #'CH4_std_rep', 'CH4_std_rep'
    #'CH4_Cstd', 
    #'is_ht_999', 'is_area_999', 'is_rt_zero', 'is_w_zero',
    'duration', 
    #'is_duration_spike',
    #'baseline_drift', 
    'ht_area_ratio',
    #'type_air', 'type_blank', 'type_cal', 'type_other', 'type_std', 'type_tank',
    #'year', 'month', 'day', 'hour', 'minute', 'seconds'
]

# %%
# 
def types_convert(type_name):
    """
    This fnuction is used for type classification
    """
    t = str(type_name).lower().strip()

    if 'cal' in t:
        return 'cal'
    elif 'std' in t:
        return 'std'
    elif 'air' == t:
        return 'air'
    elif 'tank' in t:
        return 'tank'
    elif 'blank' in t:
        return 'blank'
    else:
        return 'other'

# %%
data['type_norm'] = data['type'].apply(types_convert)
data['type_norm'].unique()
# Out:
# array(['air', 'std', 'tank', 'cal', 'blank', 'other'], dtype=object)

# %%
print(1)
# Out:
# 1

# %%
print(2)
