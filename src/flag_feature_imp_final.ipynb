# %%
# data tools and plotting

from feature_eng import TSFE
import logging
import warnings
import os
from pandas.errors import PerformanceWarning
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=PerformanceWarning)
#====================
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000);
#=========================
#=============== feature engineering and define the needed features

feature_cols= [#'datetime', 
  #'tamb',  'pamb' ,
  #'psamp',
  'type',
  'pflow', 'tmod',  'CH4_rt', 'CH4_w',
       'CH4_ht', 'CH4_area', 'CH4_skew', 'CH4_start_time', 'CH4_end_time',
       'CH4_start_level', 'CH4_end_level', #'duration', 
       'is_air','is_std',
       #'previous_type_std', 'previous_type_air','next_type_std', 'next_type_air', 
       ]

feature_config ={
    'diff':{'cols': ['CH4_area', 
                    'CH4_ht','CH4_w' , 'CH4_rt' #'tmod',#'CH4_end_time','CH4_start_time',,'CH4_rt'
                ], 'periods':[1, 3, 6, 72]},

    'lag':{'cols':['CH4_area', 'CH4_rt',  'CH4_ht', #'tmod',  'psamp','pamb','tamb',,'CH4_skew'
                'pflow',
              'CH4_w'], 'periods':[1, 3, 6, 72]},

    'diff_cross':{'cols':[['CH4_ht', 'CH4_ht_lag_72'],
                          ['CH4_area', 'CH4_area_lag_72'],
                          ['CH4_end_time', 'CH4_start_time'],
                      # ['CH4_w_roll_mean_2h', 'CH4_w_roll_mean_7h'],
                        ['CH4_end_level', 'CH4_start_level'],
                        ['CH4_rt', 'pflow'],
                        #['CH4_ht', 'CH4_ht_lag_72'],['CH4_w', 'CH4_w_lag_72'],
                        #['pflow', 'pflow_lag_1'],['CH4_skew','CH4_skew_lag_1']
                        ]}, 

    'roll_std':{'cols': ['CH4_w', 'CH4_ht','CH4_area', 'CH4_end_time_CH4_start_time_diff_cross'], 'period':['1h','3h','6h', '24h', '3D', '7D']},

    'roll_mean_percent_res':{'cols':['CH4_rt' ,
                             'CH4_w', 'CH4_ht','CH4_area',], 'period': ['1h','3h','6h','24h', '3D', '7D']},



    #'log':{'cols':['last_std_CH4_ht','last_air_CH4_ht'
                   #'CH4_end_time', 
     #              ]},
     'roll_median':{'cols':['CH4_rt' ,
                             'CH4_w', 'CH4_ht','CH4_area', 'pflow','CH4_area_lag_72','CH4_ht_lag_72'], 'period':['1h','3h','6h', '24h', '3D', '7D']},
     'roll_mad':{'cols':['CH4_rt' ,
                             'CH4_w', 'CH4_ht','CH4_area', 'pflow'], 'period':['1h','3h','6h', '24h', '3D', '7D']},
     'roll_median_percent_res':{'cols':['CH4_rt' ,
                             'CH4_w', 'CH4_ht','CH4_area','pflow','CH4_area_lag_72','CH4_ht_lag_72'],
                              'period':['1h','3h','6h', '24h', '3D', '7D']},

   # 'multi':{'cols':[['CH4_w', 'CH4_ht'],['CH4_area', 'pflow']]},

    'ratio':{'cols':[   ['CH4_skew','CH4_w'],
                        ['CH4_ht', 'pflow'],
                        ['CH4_ht', 'CH4_w'],
                        ['CH4_area', 'pflow'],
                        ['CH4_rt', 'pflow'],
                        ['CH4_ht', 'CH4_area'],
                        ['CH4_w', 'CH4_end_time_CH4_start_time_diff_cross'],
                       # ['CH4_rt', 'CH4_end_time_CH4_start_time_diff_cross'],

                       # ['CH4_ht', 'last_air_ht'],
                        #['CH4_w_roll_std_2h', 'CH4_w_roll_std_1D'],
                      
                        ['CH4_start_level', 'CH4_end_level'],
                  
                        ['CH4_w_roll_std_3h', 'CH4_w_roll_mean_3h'], ['CH4_ht_roll_std_3h', 'CH4_ht_roll_mean_3h'],['CH4_area_roll_std_3h', 'CH4_area_roll_mean_3h'],
                        ['CH4_w_roll_std_24h', 'CH4_w_roll_mean_24h'], ['CH4_ht_roll_std_24h', 'CH4_ht_roll_mean_24h'],['CH4_area_roll_std_24h', 'CH4_area_roll_mean_24h'],
                        #['CH4_w_roll_std_6h', 'CH4_w_roll_mean_6h'], ['CH4_ht_roll_std_6h', 'CH4_ht_roll_mean_6h'],['CH4_area_roll_std_6h', 'CH4_area_roll_mean_6h'],
                        #['CH4_ht_roll_std_24h', 'CH4_ht_roll_mean_24h']
                       # ['CH4_w_roll_std_7h', 'CH4_w_roll_mean_7h'],['CH4_ht_roll_std_7h', 'CH4_ht_roll_mean_7h'],
                        #['CH4_w_roll_std_2D', 'CH4_w_roll_mean_2D'],['CH4_ht_roll_std_2D', 'CH4_ht_roll_mean_2D'],
                        #['CH4_rt', 'last_std_rt'],
                        
                       #['CH4_end_time', 'CH4_start_time'], ['CH4_area', 'pflow'],  ['CH4_skew', 'CH4_w'],['CH4_w', 'CH4_ht']
                       ]}, 


    'per_change':{'cols':[['CH4_ht_diff_1', 'CH4_ht_lag_1']]},
    'relative_per': {'cols': ['CH4_w', 'CH4_ht'], 'period':['2h','7h']},
    'Z_score_res':{'cols':[['CH4_w', 'CH4_w_roll_mean_3h', 'CH4_w_roll_std_3h', '3h'], #['CH4_end_time', 'CH4_end_time_roll_mean_7D', 'CH4_end_time_roll_std_7D', '7D']
                           ]},
    'per_rank': {'cols': ['CH4_w', 'CH4_skew','CH4_ht'], 'period':['7D']},


}

# %%
df = pd.read_csv('../data/processed/mhd_ch4_cnan_v1.csv', index_col= 'datetime')
df = df.drop(df[df['year']==2026].index)

df.columns.tolist()
# Out:
# ['date',
#  'time',
#  'type',
#  'sample',
#  'standard',
#  'port',
#  'ht',
#  'tmod',
#  'tamb',
#  'lab_temp',
#  'pflow',
#  'psamp',
#  'ploop',
#  'pamb',
#  'CH4_rt',
#  'CH4_w',
#  'CH4_ht',
#  'CH4_area',
#  'CH4_skew',
#  'CH4_start_time',
#  'CH4_end_time',
#  'CH4_start_level',
#  'CH4_end_level',
#  'CH4_Rl_ht',
#  'CH4_Rl_a',
#  'CH4_Rl',
#  'CH4_norm_ht',
#  'CH4_norm_a',
#  'CH4_norm_w',
#  'CH4_R_ht',
#  'CH4_R_a',
#  'CH4_R',
#  'CH4_C_ht',
#  'CH4_C_a',
#  'CH4_C',
#  'CH4_std_stdev',
#  'CH4_std_rep',
#  'CH4_Cstd',
#  'CH4_flag_ht',
#  'CH4_flag_a',
#  'CH4_flag',
#  'CH4_flag_p',
#  'CH4_flag_ht_bin',
#  'CH4_flag_a_bin',
#  'label1',
#  'datetime_str',
#  'is_ht_999',
#  'is_area_999',
#  'is_rt_zero',
#  'is_w_zero',
#  'duration',
#  'is_duration_spike',
#  'baseline_drift',
#  'ht_area_ratio',
#  'last_std_time',
#  'seconds_since_last_std',
#  'type_std',
#  'type_air',
#  'type_tank',
#  'type_blank',
#  'type_cal',
#  'type_other',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'seconds',
#  'is_air',
#  'is_std',
#  'label_c_nan']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777226 entries, 1994-02-16 14:29:00 to 2025-12-31 23:58:00
# Data columns (total 71 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   date                    777226 non-null  int64
#  1   time                    777226 non-null  int64
#  2   type                    777226 non-null  object
#  3   sample                  777226 non-null  object
#  4   standard                777226 non-null  object
#  5   port                    777226 non-null  int64
#  6   ht                      777226 non-null  float64
#  7   tmod                    672468 non-null  float64
#  8   tamb                    672468 non-null  float64
#  9   lab_temp                0 non-null       float64
#  10  pflow                   775251 non-null  float64
#  11  psamp                   775257 non-null  float64
#  12  ploop                   0 non-null       float64
#  13  pamb                    775198 non-null  float64
#  14  CH4_rt                  775721 non-null  float64
#  15  CH4_w                   775721 non-null  float64
#  16  CH4_ht                  775721 non-null  float64
#  17  CH4_area                775721 non-null  float64
#  18  CH4_skew                775721 non-null  float64
#  19  CH4_start_time          775721 non-null  float64
#  20  CH4_end_time            775721 non-null  float64
#  21  CH4_start_level         775721 non-null  float64
#  22  CH4_end_level           775721 non-null  float64
#  23  CH4_Rl_ht               727259 non-null  float64
#  24  CH4_Rl_a                728995 non-null  float64
#  25  CH4_Rl                  721159 non-null  float64
#  26  CH4_norm_ht             727259 non-null  float64
#  27  CH4_norm_a              727259 non-null  float64
#  28  CH4_norm_w              727259 non-null  float64
#  29  CH4_R_ht                727259 non-null  float64
#  30  CH4_R_a                 728995 non-null  float64
#  31  CH4_R                   721159 non-null  float64
#  32  CH4_C_ht                725841 non-null  float64
#  33  CH4_C_a                 727572 non-null  float64
#  34  CH4_C                   719750 non-null  float64
#  35  CH4_std_stdev           756014 non-null  float64
#  36  CH4_std_rep             341655 non-null  float64
#  37  CH4_Cstd                777226 non-null  float64
#  38  CH4_flag_ht             777226 non-null  object
#  39  CH4_flag_a              777226 non-null  object
#  40  CH4_flag                777226 non-null  object
#  41  CH4_flag_p              777226 non-null  object
#  42  CH4_flag_ht_bin         777226 non-null  int64
#  43  CH4_flag_a_bin          777226 non-null  int64
#  44  label1                  777226 non-null  int64
#  45  datetime_str            777226 non-null  int64
#  46  is_ht_999               777226 non-null  bool
#  47  is_area_999             777226 non-null  bool
#  48  is_rt_zero              777226 non-null  bool
#  49  is_w_zero               777226 non-null  bool
#  50  duration                775721 non-null  float64
#  51  is_duration_spike       777226 non-null  bool
#  52  baseline_drift          775721 non-null  float64
#  53  ht_area_ratio           761142 non-null  float64
#  54  last_std_time           777152 non-null  object
#  55  seconds_since_last_std  777152 non-null  float64
#  56  type_std                777226 non-null  int64
#  57  type_air                777226 non-null  int64
#  58  type_tank               777226 non-null  int64
#  59  type_blank              777226 non-null  int64
#  60  type_cal                777226 non-null  int64
#  61  type_other              777226 non-null  int64
#  62  year                    777226 non-null  int64
#  63  month                   777226 non-null  int64
#  64  day                     777226 non-null  int64
#  65  hour                    777226 non-null  int64
#  66  minute                  777226 non-null  int64
#  67  seconds                 777226 non-null  int64
#  68  is_air                  777226 non-null  int64
#  69  is_std                  777226 non-null  int64
#  70  label_c_nan             777226 non-null  int64
# dtypes: bool(5), float64(36), int64(22), object(8)
# memory usage: 401.0+ MB

# %%
df.columns.tolist()
# Out:
# ['date',
#  'time',
#  'type',
#  'sample',
#  'standard',
#  'port',
#  'ht',
#  'tmod',
#  'tamb',
#  'lab_temp',
#  'pflow',
#  'psamp',
#  'ploop',
#  'pamb',
#  'CH4_rt',
#  'CH4_w',
#  'CH4_ht',
#  'CH4_area',
#  'CH4_skew',
#  'CH4_start_time',
#  'CH4_end_time',
#  'CH4_start_level',
#  'CH4_end_level',
#  'CH4_Rl_ht',
#  'CH4_Rl_a',
#  'CH4_Rl',
#  'CH4_norm_ht',
#  'CH4_norm_a',
#  'CH4_norm_w',
#  'CH4_R_ht',
#  'CH4_R_a',
#  'CH4_R',
#  'CH4_C_ht',
#  'CH4_C_a',
#  'CH4_C',
#  'CH4_std_stdev',
#  'CH4_std_rep',
#  'CH4_Cstd',
#  'CH4_flag_ht',
#  'CH4_flag_a',
#  'CH4_flag',
#  'CH4_flag_p',
#  'CH4_flag_ht_bin',
#  'CH4_flag_a_bin',
#  'label1',
#  'datetime_str',
#  'is_ht_999',
#  'is_area_999',
#  'is_rt_zero',
#  'is_w_zero',
#  'duration',
#  'is_duration_spike',
#  'baseline_drift',
#  'ht_area_ratio',
#  'last_std_time',
#  'seconds_since_last_std',
#  'type_std',
#  'type_air',
#  'type_tank',
#  'type_blank',
#  'type_cal',
#  'type_other',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'seconds',
#  'is_air',
#  'is_std',
#  'label_c_nan']

# %% [markdown]
# #  Label1

# %% [markdown]
# #=====================ml PART

# %%
target ='label1'

# %%
X = df[feature_cols]
y = df[target]
split_idx = int(len(df)*0.8)

X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]


tscv = TimeSeriesSplit(n_splits=5)
print(X.columns)
X_train.head()
# Out:
# Index(['type', 'pflow', 'tmod', 'CH4_rt', 'CH4_w', 'CH4_ht', 'CH4_area',
#        'CH4_skew', 'CH4_start_time', 'CH4_end_time', 'CH4_start_level',
#        'CH4_end_level', 'is_air', 'is_std'],
#       dtype='object')
#                     type  pflow   tmod  CH4_rt  CH4_w    CH4_ht   CH4_area  \
# datetime
# 1994-02-16 14:29:00  air  841.9  40.00     0.0   0.00       0.0        0.0
# 1994-02-16 14:49:00  air  840.4  40.00     0.0   0.00       0.0        0.0
# 1994-02-16 15:09:00  air  839.4  40.01   109.8   2.60  190908.0   496440.0
# 1994-02-16 15:29:00  air  839.6  40.00    94.8   6.85  151667.0  1065982.0
# 1994-02-16 18:00:00  air  845.4  40.00     0.0   0.00       0.0        0.0
#
#                      CH4_skew  CH4_start_time  CH4_end_time  CH4_start_level  \
# datetime
# 1994-02-16 14:29:00      0.00             0.0           0.0              0.0
# 1994-02-16 14:49:00      0.00             0.0           0.0              0.0
# 1994-02-16 15:09:00      0.63           102.0         135.4          10063.0
# 1994-02-16 15:29:00      1.02            86.2         129.0          99999.0
# 1994-02-16 18:00:00      0.00             0.0           0.0              0.0
#
#                      CH4_end_level  is_air  is_std
# datetime
# 1994-02-16 14:29:00            0.0       1       0
# 1994-02-16 14:49:00            0.0       1       0
# 1994-02-16 15:09:00        10029.0       1       0
# 1994-02-16 15:29:00        99999.0       1       0
# 1994-02-16 18:00:00            0.0       1       0

# %%
from pulearn import ElkanotoPuClassifier
from sklearn.ensemble import RandomForestClassifier
tsfe = TSFE(feature_cols=feature_cols, feature_config=feature_config)
X_train_final = tsfe.transform(X_train)

X_test_final = tsfe.transform(X_test)
X_train_final.columns.tolist()
# Out:
# ['type',
#  'pflow',
#  'tmod',
#  'CH4_rt',
#  'CH4_w',
#  'CH4_ht',
#  'CH4_area',
#  'CH4_skew',
#  'CH4_start_time',
#  'CH4_end_time',
#  'CH4_start_level',
#  'CH4_end_level',
#  'is_air',
#  'is_std',
#  'last_std_CH4_ht',
#  'last_air_CH4_ht',
#  'last_std_CH4_area',
#  'last_air_CH4_area',
#  'last_std_CH4_rt',
#  'last_air_CH4_rt',
#  'last_std_CH4_start_level',
#  'last_air_CH4_start_level',
#  'CH4_ht_to_last_std_ratio',
#  'CH4_ht_to_last_air_ratio',
#  'CH4_area_to_last_std_ratio',
#  'CH4_area_to_last_air_ratio',
#  'CH4_rt_to_last_std_ratio',
#  'CH4_rt_to_last_air_ratio',
#  'CH4_start_level_to_last_std_ratio',
#  'CH4_start_level_to_last_air_ratio',
#  'duration_rt_ratio',
#  'rt_position',
#  'baseline_slope',
#  'level_area_ratio',
#  'CH4_area_diff_1',
#  'CH4_area_diff_3',
#  'CH4_area_diff_6',
#  'CH4_area_diff_72',
#  'CH4_ht_diff_1',
#  'CH4_ht_diff_3',
#  'CH4_ht_diff_6',
#  'CH4_ht_diff_72',
#  'CH4_w_diff_1',
#  'CH4_w_diff_3',
#  'CH4_w_diff_6',
#  'CH4_w_diff_72',
#  'CH4_rt_diff_1',
#  'CH4_rt_diff_3',
#  'CH4_rt_diff_6',
#  'CH4_rt_diff_72',
#  'CH4_area_lag_1',
#  'CH4_area_lag_3',
#  'CH4_area_lag_6',
#  'CH4_area_lag_72',
#  'CH4_rt_lag_1',
#  'CH4_rt_lag_3',
#  'CH4_rt_lag_6',
#  'CH4_rt_lag_72',
#  'CH4_ht_lag_1',
#  'CH4_ht_lag_3',
#  'CH4_ht_lag_6',
#  'CH4_ht_lag_72',
#  'pflow_lag_1',
#  'pflow_lag_3',
#  'pflow_lag_6',
#  'pflow_lag_72',
#  'CH4_w_lag_1',
#  'CH4_w_lag_3',
#  'CH4_w_lag_6',
#  'CH4_w_lag_72',
#  'CH4_ht_CH4_ht_lag_72_diff_cross',
#  'CH4_area_CH4_area_lag_72_diff_cross',
#  'CH4_end_time_CH4_start_time_diff_cross',
#  'CH4_end_level_CH4_start_level_diff_cross',
#  'CH4_rt_pflow_diff_cross',
#  'CH4_w_roll_std_1h',
#  'CH4_w_roll_std_3h',
#  'CH4_w_roll_std_6h',
#  'CH4_w_roll_std_24h',
#  'CH4_w_roll_std_3D',
#  'CH4_w_roll_std_7D',
#  'CH4_ht_roll_std_1h',
#  'CH4_ht_roll_std_3h',
#  'CH4_ht_roll_std_6h',
#  'CH4_ht_roll_std_24h',
#  'CH4_ht_roll_std_3D',
#  'CH4_ht_roll_std_7D',
#  'CH4_area_roll_std_1h',
#  'CH4_area_roll_std_3h',
#  'CH4_area_roll_std_6h',
#  'CH4_area_roll_std_24h',
#  'CH4_area_roll_std_3D',
#  'CH4_area_roll_std_7D',
#  'CH4_end_time_CH4_start_time_diff_cross_roll_std_1h',
#  'CH4_end_time_CH4_start_time_diff_cross_roll_std_3h',
#  'CH4_end_time_CH4_start_time_diff_cross_roll_std_6h',
#  'CH4_end_time_CH4_start_time_diff_cross_roll_std_24h',
#  'CH4_end_time_CH4_start_time_diff_cross_roll_std_3D',
#  'CH4_end_time_CH4_start_time_diff_cross_roll_std_7D',
#  'CH4_rt_roll_mean_1h',
#  'CH4_rt_residual_1h',
#  'CH4_rt_roll_mean_3h',
#  'CH4_rt_residual_3h',
#  'CH4_rt_roll_mean_6h',
#  'CH4_rt_residual_6h',
#  'CH4_rt_roll_mean_24h',
#  'CH4_rt_residual_24h',
#  'CH4_rt_roll_mean_3D',
#  'CH4_rt_residual_3D',
#  'CH4_rt_roll_mean_7D',
#  'CH4_rt_residual_7D',
#  'CH4_w_roll_mean_1h',
#  'CH4_w_residual_1h',
#  'CH4_w_roll_mean_3h',
#  'CH4_w_residual_3h',
#  'CH4_w_roll_mean_6h',
#  'CH4_w_residual_6h',
#  'CH4_w_roll_mean_24h',
#  'CH4_w_residual_24h',
#  'CH4_w_roll_mean_3D',
#  'CH4_w_residual_3D',
#  'CH4_w_roll_mean_7D',
#  'CH4_w_residual_7D',
#  'CH4_ht_roll_mean_1h',
#  'CH4_ht_residual_1h',
#  'CH4_ht_roll_mean_3h',
#  'CH4_ht_residual_3h',
#  'CH4_ht_roll_mean_6h',
#  'CH4_ht_residual_6h',
#  'CH4_ht_roll_mean_24h',
#  'CH4_ht_residual_24h',
#  'CH4_ht_roll_mean_3D',
#  'CH4_ht_residual_3D',
#  'CH4_ht_roll_mean_7D',
#  'CH4_ht_residual_7D',
#  'CH4_area_roll_mean_1h',
#  'CH4_area_residual_1h',
#  'CH4_area_roll_mean_3h',
#  'CH4_area_residual_3h',
#  'CH4_area_roll_mean_6h',
#  'CH4_area_residual_6h',
#  'CH4_area_roll_mean_24h',
#  'CH4_area_residual_24h',
#  'CH4_area_roll_mean_3D',
#  'CH4_area_residual_3D',
#  'CH4_area_roll_mean_7D',
#  'CH4_area_residual_7D',
#  'CH4_rt_roll_median_1h',
#  'CH4_rt_roll_median_3h',
#  'CH4_rt_roll_median_6h',
#  'CH4_rt_roll_median_24h',
#  'CH4_rt_roll_median_3D',
#  'CH4_rt_roll_median_7D',
#  'CH4_w_roll_median_1h',
#  'CH4_w_roll_median_3h',
#  'CH4_w_roll_median_6h',
#  'CH4_w_roll_median_24h',
#  'CH4_w_roll_median_3D',
#  'CH4_w_roll_median_7D',
#  'CH4_ht_roll_median_1h',
#  'CH4_ht_roll_median_3h',
#  'CH4_ht_roll_median_6h',
#  'CH4_ht_roll_median_24h',
#  'CH4_ht_roll_median_3D',
#  'CH4_ht_roll_median_7D',
#  'CH4_area_roll_median_1h',
#  'CH4_area_roll_median_3h',
#  'CH4_area_roll_median_6h',
#  'CH4_area_roll_median_24h',
#  'CH4_area_roll_median_3D',
#  'CH4_area_roll_median_7D',
#  'pflow_roll_median_1h',
#  'pflow_roll_median_3h',
#  'pflow_roll_median_6h',
#  'pflow_roll_median_24h',
#  'pflow_roll_median_3D',
#  'pflow_roll_median_7D',
#  'CH4_area_lag_72_roll_median_1h',
#  'CH4_area_lag_72_roll_median_3h',
#  'CH4_area_lag_72_roll_median_6h',
#  'CH4_area_lag_72_roll_median_24h',
#  'CH4_area_lag_72_roll_median_3D',
#  'CH4_area_lag_72_roll_median_7D',
#  'CH4_ht_lag_72_roll_median_1h',
#  'CH4_ht_lag_72_roll_median_3h',
#  'CH4_ht_lag_72_roll_median_6h',
#  'CH4_ht_lag_72_roll_median_24h',
#  'CH4_ht_lag_72_roll_median_3D',
#  'CH4_ht_lag_72_roll_median_7D',
#  'CH4_rt_mad_1h',
#  'CH4_rt_mad_3h',
#  'CH4_rt_mad_6h',
#  'CH4_rt_mad_24h',
#  'CH4_rt_mad_3D',
#  'CH4_rt_mad_7D',
#  'CH4_w_mad_1h',
#  'CH4_w_mad_3h',
#  'CH4_w_mad_6h',
#  'CH4_w_mad_24h',
#  'CH4_w_mad_3D',
#  'CH4_w_mad_7D',
#  'CH4_ht_mad_1h',
#  'CH4_ht_mad_3h',
#  'CH4_ht_mad_6h',
#  'CH4_ht_mad_24h',
#  'CH4_ht_mad_3D',
#  'CH4_ht_mad_7D',
#  'CH4_area_mad_1h',
#  'CH4_area_mad_3h',
#  'CH4_area_mad_6h',
#  'CH4_area_mad_24h',
#  'CH4_area_mad_3D',
#  'CH4_area_mad_7D',
#  'pflow_mad_1h',
#  'pflow_mad_3h',
#  'pflow_mad_6h',
#  'pflow_mad_24h',
#  'pflow_mad_3D',
#  'pflow_mad_7D',
#  'CH4_rt_robust_residual_1h',
#  'CH4_rt_robust_residual_3h',
#  'CH4_rt_robust_residual_6h',
#  'CH4_rt_robust_residual_24h',
#  'CH4_rt_robust_residual_3D',
#  'CH4_rt_robust_residual_7D',
#  'CH4_w_robust_residual_1h',
#  'CH4_w_robust_residual_3h',
#  'CH4_w_robust_residual_6h',
#  'CH4_w_robust_residual_24h',
#  'CH4_w_robust_residual_3D',
#  'CH4_w_robust_residual_7D',
#  'CH4_ht_robust_residual_1h',
#  'CH4_ht_robust_residual_3h',
#  'CH4_ht_robust_residual_6h',
#  'CH4_ht_robust_residual_24h',
#  'CH4_ht_robust_residual_3D',
#  'CH4_ht_robust_residual_7D',
#  'CH4_area_robust_residual_1h',
#  'CH4_area_robust_residual_3h',
#  'CH4_area_robust_residual_6h',
#  'CH4_area_robust_residual_24h',
#  'CH4_area_robust_residual_3D',
#  'CH4_area_robust_residual_7D',
#  'pflow_robust_residual_1h',
#  'pflow_robust_residual_3h',
#  'pflow_robust_residual_6h',
#  'pflow_robust_residual_24h',
#  'pflow_robust_residual_3D',
#  'pflow_robust_residual_7D',
#  'CH4_area_lag_72_robust_residual_1h',
#  'CH4_area_lag_72_robust_residual_3h',
#  'CH4_area_lag_72_robust_residual_6h',
#  'CH4_area_lag_72_robust_residual_24h',
#  'CH4_area_lag_72_robust_residual_3D',
#  'CH4_area_lag_72_robust_residual_7D',
#  'CH4_ht_lag_72_robust_residual_1h',
#  'CH4_ht_lag_72_robust_residual_3h',
#  'CH4_ht_lag_72_robust_residual_6h',
#  'CH4_ht_lag_72_robust_residual_24h',
#  'CH4_ht_lag_72_robust_residual_3D',
#  'CH4_ht_lag_72_robust_residual_7D',
#  'CH4_skew_CH4_w_ratio',
#  'CH4_ht_pflow_ratio',
#  'CH4_ht_CH4_w_ratio',
#  'CH4_area_pflow_ratio',
#  'CH4_rt_pflow_ratio',
#  'CH4_ht_CH4_area_ratio',
#  'CH4_w_CH4_end_time_CH4_start_time_diff_cross_ratio',
#  'CH4_start_level_CH4_end_level_ratio',
#  'CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio',
#  'CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio',
#  'CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio',
#  'CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio',
#  'CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio',
#  'CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio',
#  'CH4_ht_diff_1_CH4_ht_lag_1_per_change',
#  'CH4_w_relative_per_2h',
#  'CH4_w_relative_per_7h',
#  'CH4_ht_relative_per_2h',
#  'CH4_ht_relative_per_7h',
#  'CH4_w_3h_zcore_res_gen',
#  'CH4_w_per_rank_7D',
#  'CH4_skew_per_rank_7D',
#  'CH4_ht_per_rank_7D']

# %%
X_train_final, X_test_final = (X_train_final.drop(columns='type'), 
                               X_test_final.drop(columns='type'))

# %% [markdown]
# #selected_features = slected_col(X_train_final)
# #X_train_final  = X_train_final [feature_ml]
#
#
# #X_test_final  = X_test_final [feature_ml]

# %% [markdown]
# if mean is high but cv is high also,
# that means the importance of feature relys on what kind of sample selected
# for example: CH4_w_residual_3h :top 7,  cv is 40.536725 -> importance highly relates to the data selected (may not be so stable)

# %%
def bagging_rf(n_bags, X_train_final, y_train):
    pos_idx = np.flatnonzero(y_train.to_numpy() == 1)
    unl_idx = np.flatnonzero(y_train.to_numpy() == 0)

    # obtain the number of positive and unlabeled data
    print(f"Number of Bag: {n_bags}")
    number_pos = len(pos_idx)
    print("Positive:", len(pos_idx))
    print("Unlabeled:", len(unl_idx))

    rng = np.random.default_rng(42)

    feature_importances = []
    models = []

    for bag in range(n_bags):
        sampled_pos = pos_idx

        #select same number data of positive data from unlabeld data
        sampled_unl_idx = rng.choice(
            unl_idx,
            size=number_pos,
            replace=False
        )

        sampled_idx = np.concatenate([
            pos_idx,
            sampled_unl_idx
        ])


        rng.shuffle(sampled_idx)

        X_pu = X_train_final.iloc[sampled_idx]
        y_pu = y_train.iloc[sampled_idx]

        print(
            f"\n PU training data, Bag {bag +1}/{n_bags} "
            f"Positive = {(y_pu ==1).sum()}, "
            f"Unlabeled = {(y_pu == 0).sum()}"
        )

        # base model
        base_rf = RandomForestClassifier(
            random_state=42
        )

        # fit model
        base_rf.fit(X_pu, y_pu)

        # 紀錄模型
        models.append(base_rf)

        #紀錄特徵重要性
        feature_importances.append(
            base_rf.feature_importances_
        )

    # 
    importance_df = pd.DataFrame(
        feature_importances,
        columns=X_train_final.columns
    )

    # 計算平均特徵重要性、標準差、coefficient of variation以百分比顯示，由高到低排序
    importance_summary = pd.DataFrame({
        "Feature": X_train_final.columns,
        "importance_mean":importance_df.mean(axis=0),
        "importance_std": importance_df.std(axis=0),
        "importance_cv percent":(importance_df.std(axis=0) / importance_df.mean(axis=0))*100  #coefficient of variation
    }).sort_values(
        "importance_mean", ascending=False
        ).round(4)

    # 排名
    rank_df = importance_df.rank(
        axis=1,
        ascending=False,
        method="average"
    ) # rank in every bag iter

    # 平均排名、
    rank_summary = pd.DataFrame({
        "Feature": X_train_final.columns,
            "rank_mean":rank_df.mean(axis=0),
            "rank_std": rank_df.std(axis=0),
            "rank_cv percent":(rank_df.std(axis=0) / rank_df.mean(axis=0))*100  #coefficient of variation
        }).sort_values(
            "rank_mean", ascending = True
            ).round(4)
    return models, importance_summary, rank_summary

# %% [markdown]
# #### Bagging for 20 bags

# %%
models_10, importance_summary_10, rank_10 = bagging_rf(10, X_train_final, y_train)
models_20, importance_summary_20, rank_20 = bagging_rf(20, X_train_final, y_train)
models_30, importance_summary_30, rank_30 = bagging_rf(30, X_train_final, y_train)
# Out:
# Number of Bag: 10
# Positive: 21442
# Unlabeled: 600338
#
#  PU training data, Bag 1/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 2/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 3/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 4/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 5/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 6/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 7/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 8/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 9/10 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 10/10 Positive = 21442, Unlabeled = 21442
# Number of Bag: 20
# Positive: 21442
# Unlabeled: 600338
#
#  PU training data, Bag 1/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 2/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 3/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 4/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 5/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 6/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 7/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 8/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 9/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 10/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 11/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 12/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 13/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 14/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 15/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 16/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 17/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 18/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 19/20 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 20/20 Positive = 21442, Unlabeled = 21442
# Number of Bag: 30
# Positive: 21442
# Unlabeled: 600338
#
#  PU training data, Bag 1/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 2/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 3/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 4/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 5/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 6/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 7/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 8/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 9/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 10/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 11/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 12/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 13/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 14/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 15/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 16/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 17/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 18/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 19/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 20/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 21/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 22/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 23/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 24/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 25/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 26/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 27/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 28/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 29/30 Positive = 21442, Unlabeled = 21442
#
#  PU training data, Bag 30/30 Positive = 21442, Unlabeled = 21442

# %% [markdown]
# 87 mins

# %% [markdown]
# =====

# %%
os.makedirs('csv', exist_ok=True) 
importance_summary_10.to_csv("csv/importance_summary_10.csv", index=False)
importance_summary_20.to_csv("csv/importance_summary_20.csv", index=False)
importance_summary_30.to_csv("csv/importance_summary_30.csv", index=False)
rank_10.to_csv("csv/rank_10.csv", index=False)
rank_20.to_csv("csv/rank_20.csv", index=False)
rank_30.to_csv("csv/rank_30.csv", index=False)

# %%
importance_summary_10 = pd.read_csv("csv/importance_summary_10.csv")
importance_summary_20= pd.read_csv("csv/importance_summary_20.csv")
importance_summary_30= pd.read_csv("csv/importance_summary_30.csv")
rank_10 = pd.read_csv("csv/rank_10.csv")
rank_20 = pd.read_csv("csv/rank_20.csv")
rank_30 = pd.read_csv("csv/rank_30.csv")

# %% [markdown]
# ### Visulize feature importance

# %%
importance_compare = pd.concat({
  
    "10 bag": importance_summary_10.set_index("Feature")["importance_mean"],
    "20 bag": importance_summary_20.set_index("Feature")["importance_mean"],
    "30 bag": importance_summary_30.set_index("Feature")["importance_mean"]
}, axis = 1)

importance_compare
# Out:
#                                                     10 bag  20 bag  30 bag
# Feature
# CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio      0.0283  0.0288  0.0289
# CH4_rt_to_last_air_ratio                            0.0247  0.0248  0.0250
# CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio  0.0244  0.0246  0.0246
# CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio    0.0193  0.0188  0.0185
# CH4_w_residual_6h                                   0.0188  0.0178  0.0177
# duration_rt_ratio                                   0.0188  0.0188  0.0188
# rt_position                                         0.0187  0.0184  0.0186
# CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio        0.0186  0.0187  0.0187
# CH4_ht_to_last_std_ratio                            0.0185  0.0186  0.0186
# CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio        0.0173  0.0173  0.0173
# CH4_end_time                                        0.0173  0.0174  0.0173
# CH4_rt_pflow_ratio                                  0.0166  0.0169  0.0164
# level_area_ratio                                    0.0158  0.0158  0.0159
# CH4_w_residual_3h                                   0.0142  0.0139  0.0140
# CH4_w_robust_residual_3h                            0.0136  0.0144  0.0142
# CH4_w_robust_residual_6h                            0.0136  0.0134  0.0136
# CH4_start_level_to_last_std_ratio                   0.0129  0.0120  0.0122
# CH4_area_residual_1h                                0.0123  0.0124  0.0124
# CH4_area_robust_residual_1h                         0.0123  0.0126  0.0124
# CH4_area_to_last_std_ratio                          0.0121  0.0119  0.0123
# CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio          0.0117  0.0119  0.0118
# CH4_ht_residual_1h                                  0.0117  0.0110  0.0108
# CH4_area_diff_1                                     0.0114  0.0115  0.0114
# CH4_w_residual_24h                                  0.0111  0.0110  0.0110
# CH4_ht_pflow_ratio                                  0.0110  0.0112  0.0112
# CH4_w_diff_1                                        0.0108  0.0108  0.0110
# CH4_start_time                                      0.0106  0.0106  0.0106
# CH4_ht_diff_1_CH4_ht_lag_1_per_change               0.0106  0.0111  0.0110
# CH4_w                                               0.0104  0.0106  0.0105
# CH4_area_to_last_air_ratio                          0.0102  0.0101  0.0101
# CH4_ht_diff_1                                       0.0092  0.0087  0.0091
# CH4_w_diff_3                                        0.0090  0.0086  0.0086
# CH4_end_time_CH4_start_time_diff_cross              0.0090  0.0086  0.0085
# CH4_w_robust_residual_1h                            0.0089  0.0089  0.0089
# CH4_w_residual_1h                                   0.0087  0.0089  0.0088
# CH4_rt_to_last_std_ratio                            0.0085  0.0077  0.0077
# CH4_w_robust_residual_24h                           0.0077  0.0077  0.0079
# CH4_skew                                            0.0077  0.0078  0.0077
# CH4_ht                                              0.0076  0.0076  0.0077
# CH4_w_diff_6                                        0.0076  0.0076  0.0078
# CH4_ht_robust_residual_1h                           0.0073  0.0080  0.0082
# CH4_rt_roll_mean_3h                                 0.0072  0.0074  0.0075
# CH4_area_roll_std_24h                               0.0069  0.0064  0.0062
# CH4_area_robust_residual_3h                         0.0068  0.0067  0.0067
# CH4_w_robust_residual_3D                            0.0067  0.0067  0.0066
# CH4_rt_pflow_diff_cross                             0.0066  0.0065  0.0067
# CH4_ht_robust_residual_3h                           0.0065  0.0059  0.0059
# is_air                                              0.0061  0.0061  0.0061
# CH4_area_residual_3h                                0.0059  0.0061  0.0061
# is_std                                              0.0058  0.0059  0.0059
# CH4_end_level                                       0.0056  0.0054  0.0053
# CH4_area_roll_std_6h                                0.0055  0.0065  0.0064
# CH4_end_time_CH4_start_time_diff_cross_roll_std...  0.0052  0.0050  0.0049
# CH4_ht_roll_mean_1h                                 0.0050  0.0052  0.0051
# CH4_w_CH4_end_time_CH4_start_time_diff_cross_ratio  0.0048  0.0048  0.0049
# CH4_start_level                                     0.0047  0.0049  0.0050
# last_air_CH4_start_level                            0.0046  0.0046  0.0046
# CH4_ht_roll_std_24h                                 0.0045  0.0041  0.0040
# CH4_w_roll_mean_3h                                  0.0045  0.0043  0.0041
# CH4_ht_roll_std_6h                                  0.0044  0.0043  0.0048
# CH4_ht_roll_std_3h                                  0.0044  0.0043  0.0039
# CH4_ht_lag_1                                        0.0041  0.0042  0.0040
# CH4_w_3h_zcore_res_gen                              0.0040  0.0039  0.0037
# CH4_rt_roll_mean_1h                                 0.0040  0.0040  0.0040
# CH4_area_roll_std_3h                                0.0040  0.0038  0.0038
# CH4_ht_residual_3h                                  0.0040  0.0044  0.0043
# CH4_ht_roll_mean_6h                                 0.0038  0.0038  0.0038
# CH4_w_roll_std_6h                                   0.0037  0.0032  0.0031
# CH4_w_relative_per_7h                               0.0037  0.0039  0.0040
# CH4_ht_relative_per_7h                              0.0036  0.0036  0.0036
# CH4_w_roll_std_24h                                  0.0035  0.0038  0.0039
# CH4_w_robust_residual_7D                            0.0035  0.0039  0.0037
# CH4_area_residual_6h                                0.0034  0.0033  0.0034
# CH4_w_residual_3D                                   0.0033  0.0038  0.0038
# CH4_ht_residual_6h                                  0.0031  0.0034  0.0033
# CH4_ht_roll_std_7D                                  0.0030  0.0028  0.0028
# CH4_area_diff_3                                     0.0030  0.0030  0.0029
# CH4_ht_roll_median_3h                               0.0030  0.0032  0.0031
# CH4_ht_to_last_air_ratio                            0.0029  0.0029  0.0029
# CH4_area_robust_residual_6h                         0.0028  0.0027  0.0028
# CH4_ht_diff_3                                       0.0028  0.0028  0.0031
# CH4_end_time_CH4_start_time_diff_cross_roll_std_7D  0.0027  0.0028  0.0028
# CH4_w_residual_7D                                   0.0026  0.0028  0.0028
# CH4_ht_robust_residual_6h                           0.0026  0.0027  0.0026
# CH4_rt_roll_mean_7D                                 0.0026  0.0027  0.0027
# CH4_area_roll_std_3D                                0.0026  0.0025  0.0025
# last_std_CH4_ht                                     0.0026  0.0025  0.0025
# last_std_CH4_area                                   0.0025  0.0026  0.0025
# CH4_w_roll_std_7D                                   0.0025  0.0025  0.0025
# CH4_rt_roll_mean_3D                                 0.0025  0.0026  0.0026
# CH4_area_roll_std_7D                                0.0025  0.0027  0.0027
# CH4_rt_roll_mean_24h                                0.0025  0.0025  0.0025
# CH4_w_relative_per_2h                               0.0024  0.0024  0.0024
# CH4_end_time_CH4_start_time_diff_cross_roll_std_3D  0.0024  0.0024  0.0023
# CH4_rt_roll_median_3D                               0.0024  0.0023  0.0023
# CH4_area                                            0.0024  0.0028  0.0029
# CH4_ht_roll_std_3D                                  0.0023  0.0025  0.0024
# CH4_start_level_CH4_end_level_ratio                 0.0023  0.0022  0.0022
# CH4_area_residual_7D                                0.0023  0.0022  0.0025
# CH4_area_roll_median_7D                             0.0022  0.0023  0.0023
# CH4_ht_mad_6h                                       0.0022  0.0021  0.0021
# CH4_area_lag_72_roll_median_7D                      0.0022  0.0022  0.0021
# CH4_start_level_to_last_air_ratio                   0.0022  0.0023  0.0023
# CH4_w_roll_std_3D                                   0.0021  0.0022  0.0023
# CH4_ht_mad_3D                                       0.0021  0.0020  0.0020
# baseline_slope                                      0.0021  0.0022  0.0022
# CH4_end_time_CH4_start_time_diff_cross_roll_std_6h  0.0021  0.0024  0.0025
# CH4_rt_roll_mean_6h                                 0.0021  0.0021  0.0020
# pflow_roll_median_7D                                0.0021  0.0020  0.0020
# CH4_end_level_CH4_start_level_diff_cross            0.0020  0.0021  0.0021
# CH4_w_roll_mean_24h                                 0.0020  0.0020  0.0021
# CH4_rt_lag_1                                        0.0020  0.0019  0.0020
# CH4_w_diff_72                                       0.0020  0.0017  0.0018
# CH4_w_roll_mean_6h                                  0.0020  0.0020  0.0020
# CH4_w_roll_mean_3D                                  0.0020  0.0020  0.0020
# CH4_area_mad_6h                                     0.0019  0.0020  0.0020
# CH4_ht_mad_24h                                      0.0019  0.0019  0.0019
# CH4_ht_CH4_w_ratio                                  0.0019  0.0018  0.0017
# last_std_CH4_start_level                            0.0019  0.0019  0.0019
# CH4_rt_roll_median_7D                               0.0019  0.0019  0.0019
# CH4_w_roll_median_3D                                0.0019  0.0018  0.0019
# pflow_roll_median_3D                                0.0019  0.0018  0.0018
# CH4_area_mad_3h                                     0.0018  0.0018  0.0018
# CH4_w_roll_mean_1h                                  0.0018  0.0016  0.0015
# CH4_ht_CH4_area_ratio                               0.0018  0.0018  0.0019
# CH4_w_roll_mean_7D                                  0.0018  0.0018  0.0018
# CH4_ht_residual_24h                                 0.0018  0.0017  0.0016
# CH4_area_mad_3D                                     0.0018  0.0017  0.0017
# CH4_ht_roll_median_7D                               0.0018  0.0018  0.0018
# CH4_ht_lag_72_roll_median_7D                        0.0018  0.0018  0.0018
# CH4_ht_relative_per_2h                              0.0018  0.0017  0.0018
# CH4_area_residual_24h                               0.0017  0.0016  0.0015
# pflow_lag_72                                        0.0017  0.0017  0.0016
# CH4_w_roll_median_7D                                0.0017  0.0017  0.0017
# CH4_ht_diff_6                                       0.0017  0.0017  0.0018
# CH4_w_roll_median_24h                               0.0017  0.0018  0.0018
# CH4_w_roll_median_3h                                0.0017  0.0017  0.0017
# CH4_ht_mad_7D                                       0.0017  0.0017  0.0017
# CH4_area_mad_24h                                    0.0017  0.0017  0.0017
# last_std_CH4_rt                                     0.0017  0.0016  0.0017
# CH4_area_roll_std_1h                                0.0016  0.0017  0.0017
# CH4_w_roll_median_6h                                0.0016  0.0018  0.0018
# pflow_robust_residual_6h                            0.0016  0.0016  0.0016
# CH4_area_roll_median_3D                             0.0016  0.0016  0.0016
# CH4_rt_residual_7D                                  0.0016  0.0017  0.0016
# CH4_ht_mad_3h                                       0.0016  0.0016  0.0016
# CH4_area_roll_mean_7D                               0.0016  0.0016  0.0016
# CH4_ht_roll_median_3D                               0.0015  0.0015  0.0015
# CH4_w_roll_median_1h                                0.0015  0.0015  0.0015
# CH4_rt_roll_median_24h                              0.0015  0.0016  0.0016
# CH4_w_mad_24h                                       0.0015  0.0016  0.0016
# CH4_w_lag_1                                         0.0015  0.0015  0.0014
# CH4_ht_roll_mean_7D                                 0.0015  0.0015  0.0015
# pflow_roll_median_24h                               0.0015  0.0015  0.0015
# CH4_w_lag_3                                         0.0015  0.0015  0.0015
# CH4_area_mad_7D                                     0.0015  0.0015  0.0015
# pflow_robust_residual_3h                            0.0015  0.0015  0.0015
# CH4_ht_roll_std_1h                                  0.0015  0.0014  0.0015
# CH4_ht_robust_residual_24h                          0.0015  0.0015  0.0014
# CH4_w_lag_6                                         0.0014  0.0015  0.0014
# CH4_area_diff_6                                     0.0014  0.0015  0.0016
# CH4_area_pflow_ratio                                0.0014  0.0015  0.0014
# CH4_area_lag_72_roll_median_3D                      0.0014  0.0014  0.0014
# CH4_w_roll_std_3h                                   0.0014  0.0014  0.0014
# CH4_ht_roll_mean_3h                                 0.0014  0.0014  0.0014
# pflow_roll_median_6h                                0.0014  0.0014  0.0014
# CH4_rt_roll_median_3h                               0.0014  0.0014  0.0014
# pflow_lag_6                                         0.0014  0.0014  0.0014
# pflow_robust_residual_24h                           0.0014  0.0014  0.0014
# pflow_roll_median_3h                                0.0014  0.0013  0.0013
# CH4_ht_lag_72_roll_median_3D                        0.0014  0.0013  0.0013
# CH4_w_mad_3D                                        0.0013  0.0014  0.0015
# CH4_w_lag_72                                        0.0013  0.0013  0.0013
# CH4_area_robust_residual_24h                        0.0013  0.0013  0.0013
# pflow_robust_residual_7D                            0.0013  0.0013  0.0014
# CH4_rt_roll_median_6h                               0.0013  0.0014  0.0014
# pflow_mad_7D                                        0.0013  0.0013  0.0013
# CH4_area_diff_72                                    0.0013  0.0014  0.0014
# CH4_ht_robust_residual_3D                           0.0013  0.0013  0.0013
# pflow                                               0.0013  0.0013  0.0013
# pflow_roll_median_1h                                0.0013  0.0013  0.0013
# pflow_lag_3                                         0.0013  0.0013  0.0013
# pflow_lag_1                                         0.0013  0.0013  0.0013
# pflow_robust_residual_1h                            0.0013  0.0012  0.0012
# CH4_ht_roll_mean_3D                                 0.0013  0.0012  0.0012
# CH4_w_per_rank_7D                                   0.0012  0.0012  0.0012
# last_air_CH4_ht                                     0.0012  0.0012  0.0012
# CH4_area_roll_mean_3D                               0.0012  0.0013  0.0013
# last_air_CH4_rt                                     0.0012  0.0012  0.0012
# pflow_mad_3D                                        0.0012  0.0012  0.0012
# CH4_rt                                              0.0012  0.0012  0.0012
# CH4_ht_roll_mean_24h                                0.0012  0.0012  0.0012
# CH4_area_residual_3D                                0.0012  0.0012  0.0012
# CH4_rt_roll_median_1h                               0.0012  0.0012  0.0012
# pflow_robust_residual_3D                            0.0011  0.0012  0.0011
# CH4_rt_lag_3                                        0.0011  0.0011  0.0011
# CH4_area_robust_residual_3D                         0.0011  0.0011  0.0011
# CH4_ht_roll_median_24h                              0.0011  0.0011  0.0011
# CH4_rt_residual_3D                                  0.0011  0.0011  0.0011
# CH4_rt_lag_6                                        0.0011  0.0011  0.0011
# CH4_area_roll_mean_24h                              0.0011  0.0011  0.0011
# last_air_CH4_area                                   0.0011  0.0011  0.0012
# CH4_area_robust_residual_7D                         0.0011  0.0011  0.0011
# CH4_area_CH4_area_lag_72_diff_cross                 0.0011  0.0010  0.0009
# CH4_ht_residual_3D                                  0.0011  0.0010  0.0010
# CH4_area_roll_median_24h                            0.0011  0.0011  0.0011
# CH4_rt_lag_72                                       0.0011  0.0011  0.0011
# CH4_ht_roll_median_6h                               0.0011  0.0011  0.0011
# CH4_ht_roll_median_1h                               0.0011  0.0011  0.0012
# CH4_ht_lag_3                                        0.0010  0.0010  0.0010
# CH4_rt_residual_24h                                 0.0010  0.0011  0.0010
# CH4_area_roll_median_6h                             0.0010  0.0011  0.0011
# CH4_skew_CH4_w_ratio                                0.0010  0.0010  0.0010
# pflow_mad_6h                                        0.0010  0.0010  0.0010
# CH4_w_mad_7D                                        0.0010  0.0010  0.0010
# CH4_area_roll_mean_3h                               0.0010  0.0010  0.0010
# CH4_area_lag_3                                      0.0010  0.0010  0.0010
# CH4_area_roll_mean_1h                               0.0010  0.0010  0.0010
# CH4_ht_lag_6                                        0.0010  0.0010  0.0010
# CH4_ht_robust_residual_7D                           0.0010  0.0010  0.0010
# CH4_ht_per_rank_7D                                  0.0010  0.0010  0.0010
# pflow_mad_24h                                       0.0010  0.0010  0.0010
# CH4_rt_robust_residual_7D                           0.0010  0.0010  0.0010
# CH4_ht_lag_72_robust_residual_7D                    0.0010  0.0010  0.0010
# CH4_skew_per_rank_7D                                0.0010  0.0010  0.0010
# CH4_ht_residual_7D                                  0.0010  0.0010  0.0010
# CH4_area_lag_72_roll_median_24h                     0.0010  0.0009  0.0009
# CH4_area_lag_1                                      0.0010  0.0010  0.0010
# CH4_area_lag_6                                      0.0010  0.0009  0.0009
# CH4_area_roll_median_3h                             0.0009  0.0010  0.0010
# CH4_area_roll_mean_6h                               0.0009  0.0009  0.0009
# CH4_ht_lag_72_roll_median_24h                       0.0009  0.0010  0.0010
# CH4_area_lag_72_robust_residual_7D                  0.0009  0.0009  0.0009
# CH4_area_roll_median_1h                             0.0009  0.0010  0.0010
# CH4_rt_residual_6h                                  0.0009  0.0009  0.0009
# CH4_ht_lag_72_robust_residual_6h                    0.0009  0.0009  0.0009
# pflow_mad_3h                                        0.0009  0.0009  0.0009
# CH4_area_lag_72_robust_residual_6h                  0.0009  0.0009  0.0009
# CH4_area_lag_72_robust_residual_3D                  0.0009  0.0009  0.0009
# CH4_area_lag_72_robust_residual_24h                 0.0009  0.0009  0.0009
# CH4_area_lag_72_robust_residual_1h                  0.0009  0.0009  0.0009
# CH4_ht_lag_72_robust_residual_3h                    0.0009  0.0009  0.0009
# CH4_ht_lag_72_roll_median_6h                        0.0009  0.0008  0.0008
# CH4_ht_lag_72_robust_residual_3D                    0.0009  0.0009  0.0009
# CH4_ht_lag_72_robust_residual_1h                    0.0009  0.0009  0.0009
# CH4_area_lag_72_robust_residual_3h                  0.0009  0.0009  0.0009
# CH4_rt_robust_residual_3D                           0.0009  0.0009  0.0009
# CH4_ht_lag_72_robust_residual_24h                   0.0009  0.0008  0.0009
# CH4_ht_lag_72                                       0.0008  0.0008  0.0008
# CH4_ht_CH4_ht_lag_72_diff_cross                     0.0008  0.0008  0.0008
# CH4_rt_residual_3h                                  0.0008  0.0008  0.0008
# CH4_ht_diff_72                                      0.0008  0.0008  0.0008
# CH4_ht_lag_72_roll_median_3h                        0.0008  0.0008  0.0008
# CH4_ht_lag_72_roll_median_1h                        0.0008  0.0008  0.0008
# CH4_area_lag_72_roll_median_6h                      0.0008  0.0008  0.0008
# CH4_rt_robust_residual_24h                          0.0008  0.0008  0.0008
# CH4_end_time_CH4_start_time_diff_cross_roll_std_3h  0.0008  0.0008  0.0008
# CH4_area_lag_72_roll_median_3h                      0.0008  0.0008  0.0008
# CH4_area_lag_72                                     0.0008  0.0008  0.0008
# CH4_area_lag_72_roll_median_1h                      0.0008  0.0008  0.0008
# CH4_end_time_CH4_start_time_diff_cross_roll_std_1h  0.0008  0.0007  0.0007
# CH4_rt_robust_residual_3h                           0.0007  0.0007  0.0007
# CH4_rt_robust_residual_6h                           0.0007  0.0007  0.0007
# CH4_w_roll_std_1h                                   0.0007  0.0007  0.0007
# CH4_w_mad_6h                                        0.0007  0.0007  0.0007
# CH4_rt_residual_1h                                  0.0006  0.0006  0.0006
# CH4_rt_robust_residual_1h                           0.0006  0.0006  0.0006
# CH4_rt_diff_72                                      0.0006  0.0006  0.0006
# CH4_rt_mad_7D                                       0.0006  0.0006  0.0006
# CH4_rt_diff_6                                       0.0005  0.0005  0.0005
# CH4_rt_diff_3                                       0.0005  0.0005  0.0005
# CH4_rt_mad_3D                                       0.0005  0.0005  0.0005
# CH4_w_mad_3h                                        0.0004  0.0004  0.0005
# CH4_rt_diff_1                                       0.0004  0.0004  0.0004
# tmod                                                0.0003  0.0003  0.0003
# CH4_rt_mad_24h                                      0.0003  0.0003  0.0003
# CH4_rt_mad_6h                                       0.0003  0.0003  0.0003
# CH4_rt_mad_3h                                       0.0003  0.0003  0.0003
# CH4_ht_mad_1h                                       0.0001  0.0001  0.0001
# CH4_area_mad_1h                                     0.0001  0.0001  0.0001
# CH4_w_mad_1h                                        0.0000  0.0000  0.0000
# CH4_rt_mad_1h                                       0.0000  0.0000  0.0000
# pflow_mad_1h                                        0.0000  0.0000  0.0000

# %% [markdown]
# 28 above 0.001

# %%
top50 = importance_summary_30.head(50)["Feature"]
plot_data = importance_compare.loc[top50]

plt.figure(figsize=(8, 10))

sns.heatmap(
    plot_data,
    annot=True,
    fmt=".4f"
)

plt.xlabel("number pf Bags")
plt.ylabel("Feature")
plt.title("Feature Importance vs Number of PU Bags Tpp 50")
plt.tight_layout()
plt.show()

plt.savefig("img/Fea_imp10_30_compare.png")

# %% [markdown]
# ### CV performance

# %%
cv_compare = pd.concat({
    "10 bag": importance_summary_10.set_index("Feature")["importance_cv percent"],
    "20 bag": importance_summary_20.set_index("Feature")["importance_cv percent"],
    "30 bag": importance_summary_30.set_index("Feature")["importance_cv percent"]
}, axis = 1)

cv_compare
# Out:
#                                                      10 bag   20 bag   30 bag
# Feature
# CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio       4.7970   5.9426   5.6230
# CH4_rt_to_last_air_ratio                             5.6817   5.2075   4.4341
# CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio   5.4440   6.3461   6.6622
# CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio     5.0554   5.8163   5.9906
# CH4_w_residual_6h                                   19.5203  25.2046  25.3296
# duration_rt_ratio                                    2.0085   1.8314   1.6857
# rt_position                                          3.8718   5.7866   5.3117
# CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio        10.8394  10.9127   9.6370
# CH4_ht_to_last_std_ratio                             2.5882   3.1683   3.3578
# CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio         4.9388   5.1800   4.8276
# CH4_end_time                                         2.3566   4.6565   3.9526
# CH4_rt_pflow_ratio                                  13.0029  14.5652  15.5677
# level_area_ratio                                     2.5620   2.6476   2.9373
# CH4_w_residual_3h                                   26.9913  24.3395  23.8251
# CH4_w_robust_residual_3h                            14.5021  23.2024  20.3674
# CH4_w_robust_residual_6h                            16.0408  14.8777  15.3319
# CH4_start_level_to_last_std_ratio                   17.7636  20.5949  19.0897
# CH4_area_residual_1h                                 7.9067   7.7826   7.2944
# CH4_area_robust_residual_1h                          6.1082   7.6364   7.4716
# CH4_area_to_last_std_ratio                          14.8842  14.3014  13.9336
# CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio           4.6076   4.0716   3.7149
# CH4_ht_residual_1h                                  16.1921  16.8406  15.4531
# CH4_area_diff_1                                      7.5461   8.3254   9.0973
# CH4_w_residual_24h                                  22.1950  19.5877  19.0031
# CH4_ht_pflow_ratio                                   3.4352   6.9026   7.4812
# CH4_w_diff_1                                        22.3153  23.0994  23.4285
# CH4_start_time                                       1.5722   1.8406   1.9018
# CH4_ht_diff_1_CH4_ht_lag_1_per_change               23.5843  18.3694  18.6700
# CH4_w                                                9.6209   6.9230   9.5839
# CH4_area_to_last_air_ratio                          20.8498  24.7515  27.3879
# CH4_ht_diff_1                                       14.6761  17.7602  17.7647
# CH4_w_diff_3                                        27.9666  26.2554  24.6831
# CH4_end_time_CH4_start_time_diff_cross              13.9506  18.8173  18.6624
# CH4_w_robust_residual_1h                            23.4707  24.1413  23.8879
# CH4_w_residual_1h                                   19.4816  20.8393  19.9468
# CH4_rt_to_last_std_ratio                            29.7254  31.9876  32.5847
# CH4_w_robust_residual_24h                           13.7066  18.6495  19.5205
# CH4_skew                                            13.3725  14.7135  12.4006
# CH4_ht                                               3.4037   3.0078   3.4407
# CH4_w_diff_6                                        22.0287  28.1204  25.9176
# CH4_ht_robust_residual_1h                           14.0967  16.6857  15.9899
# CH4_rt_roll_mean_3h                                 12.3042   8.7888  10.0764
# CH4_area_roll_std_24h                               22.7661  24.7601  26.9588
# CH4_area_robust_residual_3h                         15.4160  12.6798  11.6265
# CH4_w_robust_residual_3D                            23.8641  23.4117  22.1293
# CH4_rt_pflow_diff_cross                             30.8365  27.5378  26.9140
# CH4_ht_robust_residual_3h                           24.4681  26.9168  23.7116
# is_air                                              10.0244  10.8082  10.1328
# CH4_area_residual_3h                                 9.7140  10.9246   9.8176
# is_std                                               9.3951   8.2784   7.6061
# CH4_end_level                                       21.4976  19.4595  19.0539
# CH4_area_roll_std_6h                                20.8391  26.3008  25.8321
# CH4_end_time_CH4_start_time_diff_cross_roll_std...  19.8808  19.1647  21.2787
# CH4_ht_roll_mean_1h                                 27.5519  33.1376  32.1253
# CH4_w_CH4_end_time_CH4_start_time_diff_cross_ratio  16.0294  16.3909  15.3182
# CH4_start_level                                     37.2365  38.8997  37.4703
# last_air_CH4_start_level                             4.8448   5.0206   4.8144
# CH4_ht_roll_std_24h                                 25.1035  25.9001  24.5087
# CH4_w_roll_mean_3h                                  21.0375  24.4528  29.4382
# CH4_ht_roll_std_6h                                  27.7438  26.6758  28.5063
# CH4_ht_roll_std_3h                                  26.9882  26.1001  31.3461
# CH4_ht_lag_1                                         5.8904   5.1900  19.8931
# CH4_w_3h_zcore_res_gen                              24.5772  23.1315  22.9478
# CH4_rt_roll_mean_1h                                  4.0912   3.3838   3.4741
# CH4_area_roll_std_3h                                23.0982  20.9840  22.3395
# CH4_ht_residual_3h                                  37.1289  32.5370  30.5938
# CH4_ht_roll_mean_6h                                  2.5832   3.2208   3.3328
# CH4_w_roll_std_6h                                   16.0537  25.4253  25.4751
# CH4_w_relative_per_7h                               22.7826  25.0336  28.6477
# CH4_ht_relative_per_7h                              13.3958  14.4835  14.0023
# CH4_w_roll_std_24h                                  31.4123  31.4473  27.5575
# CH4_w_robust_residual_7D                            20.6295  22.7067  24.6648
# CH4_area_residual_6h                                16.7473  16.9580  17.1265
# CH4_w_residual_3D                                   36.9709  38.4256  34.4689
# CH4_ht_residual_6h                                  19.0826  26.9318  25.3178
# CH4_ht_roll_std_7D                                  12.1128  14.9342  13.8675
# CH4_area_diff_3                                     10.6847  11.1133  10.2569
# CH4_ht_roll_median_3h                               48.4729  41.6486  45.5861
# CH4_ht_to_last_air_ratio                             5.1990   5.6185   6.3133
# CH4_area_robust_residual_6h                         12.6526  11.2125  13.2452
# CH4_ht_diff_3                                       28.8530  27.6455  37.7706
# CH4_end_time_CH4_start_time_diff_cross_roll_std_7D  15.4812  17.2708  15.1962
# CH4_w_residual_7D                                   26.2901  21.2955  19.6953
# CH4_ht_robust_residual_6h                           38.0887  31.9021  32.7263
# CH4_rt_roll_mean_7D                                 13.8473  12.1607  12.0799
# CH4_area_roll_std_3D                                29.6935  24.6292  23.3897
# last_std_CH4_ht                                     15.7970  12.8592  12.5287
# last_std_CH4_area                                   11.0610  11.4772  10.8339
# CH4_w_roll_std_7D                                   11.9964  10.3408  13.5357
# CH4_rt_roll_mean_3D                                 11.1531  10.8209  12.1693
# CH4_area_roll_std_7D                                16.1103  16.8421  16.0323
# CH4_rt_roll_mean_24h                                 9.5518  11.5159  10.8339
# CH4_w_relative_per_2h                               18.1724  16.1920  17.4119
# CH4_end_time_CH4_start_time_diff_cross_roll_std_3D  19.5991  19.6994  18.0509
# CH4_rt_roll_median_3D                               10.9607  10.7589  11.9763
# CH4_area                                            69.6977  55.6762  55.2917
# CH4_ht_roll_std_3D                                  22.0974  22.5629  22.0464
# CH4_start_level_CH4_end_level_ratio                 13.1524  12.2200  12.5381
# CH4_area_residual_7D                                56.8203  55.5399  46.9655
# CH4_area_roll_median_7D                             21.2629  24.4370  22.8261
# CH4_ht_mad_6h                                       17.8209  15.4383  14.0530
# CH4_area_lag_72_roll_median_7D                      13.4316  13.9756  14.4646
# CH4_start_level_to_last_air_ratio                   64.3751  61.4808  61.2524
# CH4_w_roll_std_3D                                   21.4878  22.2964  22.4832
# CH4_ht_mad_3D                                       24.7581  23.3648  20.3496
# baseline_slope                                      12.7832  15.1636  14.4985
# CH4_end_time_CH4_start_time_diff_cross_roll_std_6h  21.8929  28.3467  29.3583
# CH4_rt_roll_mean_6h                                  8.8121   9.6681  10.5949
# pflow_roll_median_7D                                16.4308  16.1683  15.1050
# CH4_end_level_CH4_start_level_diff_cross            17.0099  13.6997  12.3204
# CH4_w_roll_mean_24h                                 15.4025  14.8381  14.6019
# CH4_rt_lag_1                                        72.0682  67.9254  67.5234
# CH4_w_diff_72                                       46.6972  45.5013  41.6229
# CH4_w_roll_mean_6h                                  12.6965  12.8379  12.5858
# CH4_w_roll_mean_3D                                  10.4688  11.4032  12.7294
# CH4_area_mad_6h                                     12.0061  15.8127  14.7596
# CH4_ht_mad_24h                                      16.8789  14.4445  14.2590
# CH4_ht_CH4_w_ratio                                   9.3777  11.8243  14.0010
# last_std_CH4_start_level                            16.7530  13.0284  11.2199
# CH4_rt_roll_median_7D                               13.0501  13.5479  15.1834
# CH4_w_roll_median_3D                                16.7418  17.7707  16.6262
# pflow_roll_median_3D                                12.4571  11.0260  10.7665
# CH4_area_mad_3h                                     20.2280  18.8927  17.2924
# CH4_w_roll_mean_1h                                  47.0300  40.5781  37.6980
# CH4_ht_CH4_area_ratio                               14.1269  15.2123  13.9471
# CH4_w_roll_mean_7D                                  18.4950  14.9814  14.2916
# CH4_ht_residual_24h                                 13.4447  12.5912  12.0470
# CH4_area_mad_3D                                     17.6313  22.2860  21.2431
# CH4_ht_roll_median_7D                               17.2525  18.5483  17.7615
# CH4_ht_lag_72_roll_median_7D                        12.8637  12.4879  11.9727
# CH4_ht_relative_per_2h                              18.0465  14.5974  21.6435
# CH4_area_residual_24h                               27.9546  28.5569  27.3875
# pflow_lag_72                                        18.2169  16.4567  14.7866
# CH4_w_roll_median_7D                                13.7796  14.0713  12.1896
# CH4_ht_diff_6                                       38.3990  35.9311  36.6740
# CH4_w_roll_median_24h                               18.8406  16.9425  16.5346
# CH4_w_roll_median_3h                                21.6831  18.8176  16.9906
# CH4_ht_mad_7D                                        9.6065  10.0114   9.3239
# CH4_area_mad_24h                                     7.6641  10.3538  11.7641
# last_std_CH4_rt                                     15.3473  16.7822  17.4366
# CH4_area_roll_std_1h                                15.5892  19.6858  20.7509
# CH4_w_roll_median_6h                                18.4592  18.5295  16.8938
# pflow_robust_residual_6h                             5.3716   6.6687   6.2087
# CH4_area_roll_median_3D                             16.0493  16.1918  16.5029
# CH4_rt_residual_7D                                  11.1274  12.0890  11.6189
# CH4_ht_mad_3h                                       18.7758  25.4404  23.3249
# CH4_area_roll_mean_7D                               18.0632  15.7931  14.8485
# CH4_ht_roll_median_3D                                9.0749   9.6307  10.2224
# CH4_w_roll_median_1h                                11.1876  17.1538  15.8950
# CH4_rt_roll_median_24h                              12.4282  13.9073  14.8831
# CH4_w_mad_24h                                       32.4640  32.5599  28.8300
# CH4_w_lag_1                                         12.0270  13.0332  14.4424
# CH4_ht_roll_mean_7D                                 13.6167  11.9038  13.2321
# pflow_roll_median_24h                               10.4091  11.9340  13.8104
# CH4_w_lag_3                                         14.4803  14.5679  13.4031
# CH4_area_mad_7D                                     13.1261  12.2951  12.7821
# pflow_robust_residual_3h                             3.5715   3.1736   3.7418
# CH4_ht_roll_std_1h                                  27.9995  23.5704  23.7132
# CH4_ht_robust_residual_24h                          15.2742  19.3485  18.6662
# CH4_w_lag_6                                         19.8060  16.0188  15.9231
# CH4_area_diff_6                                     14.1545  20.3355  19.8205
# CH4_area_pflow_ratio                                 9.7193  12.8236  13.6449
# CH4_area_lag_72_roll_median_3D                       8.1154  13.1559  16.0543
# CH4_w_roll_std_3h                                   23.6835  21.7380  22.2803
# CH4_ht_roll_mean_3h                                 19.3087  18.1480  20.2168
# pflow_roll_median_6h                                 7.3759   9.1770   8.7339
# CH4_rt_roll_median_3h                               12.9035  12.5087  12.7153
# pflow_lag_6                                          9.9400  12.0881  11.6720
# pflow_robust_residual_24h                            5.3576   6.4010   6.0334
# pflow_roll_median_3h                                10.0138  13.6861  12.4426
# CH4_ht_lag_72_roll_median_3D                        12.4475   9.8404   9.2095
# CH4_w_mad_3D                                        22.1550  31.3207  32.3369
# CH4_w_lag_72                                        18.9494  16.3670  16.1672
# CH4_area_robust_residual_24h                        18.0155  17.7424  19.9231
# pflow_robust_residual_7D                             6.0843   6.8256   6.9498
# CH4_rt_roll_median_6h                               13.7079  12.2925  12.2757
# pflow_mad_7D                                         4.6026   5.5267   5.7858
# CH4_area_diff_72                                    10.2226  19.3345  17.6356
# CH4_ht_robust_residual_3D                           23.8674  19.8973  19.1003
# pflow                                                8.8275  12.7109  12.0353
# pflow_roll_median_1h                                13.5437  11.7157  11.6429
# pflow_lag_3                                         11.4398  13.2311  12.1339
# pflow_lag_1                                         13.5234  10.0246  13.1214
# pflow_robust_residual_1h                             3.8237   4.6377   4.7622
# CH4_ht_roll_mean_3D                                 17.0111  13.8142  12.5586
# CH4_w_per_rank_7D                                    3.0073   3.7205   4.2795
# last_air_CH4_ht                                     15.1604  12.4047  12.5787
# CH4_area_roll_mean_3D                               15.6073  12.2083  12.9059
# last_air_CH4_rt                                     11.8706  13.0356  14.1769
# pflow_mad_3D                                         5.2404   5.8774   6.2662
# CH4_rt                                              12.1168  15.7268  13.7513
# CH4_ht_roll_mean_24h                                21.5955  19.7579  18.8738
# CH4_area_residual_3D                                18.7624  30.8176  28.1052
# CH4_rt_roll_median_1h                               15.9315  12.8787  14.1745
# pflow_robust_residual_3D                             3.7490   3.8078   4.2016
# CH4_rt_lag_3                                        11.3146  14.4247  14.8726
# CH4_area_robust_residual_3D                         12.7879  15.9525  18.7022
# CH4_ht_roll_median_24h                              10.5469  11.3578  11.3987
# CH4_rt_residual_3D                                  18.6599  14.8503  13.4748
# CH4_rt_lag_6                                        13.1982  11.9247  11.6423
# CH4_area_roll_mean_24h                              11.7728  12.1067  13.3175
# last_air_CH4_area                                   17.6810  17.9368  19.5623
# CH4_area_robust_residual_7D                         12.9582  13.9007  15.5777
# CH4_area_CH4_area_lag_72_diff_cross                 20.9750  19.3492  17.7800
# CH4_ht_residual_3D                                  21.8073  31.3162  26.7707
# CH4_area_roll_median_24h                            13.7708  12.3886  14.6394
# CH4_rt_lag_72                                        8.3562   9.8714   9.3228
# CH4_ht_roll_median_6h                               20.1835  21.0990  20.2465
# CH4_ht_roll_median_1h                               13.7228  14.7609  50.7075
# CH4_ht_lag_3                                        18.4036  15.6487  14.8444
# CH4_rt_residual_24h                                 10.3114   9.3394   8.9086
# CH4_area_roll_median_6h                             15.6170  18.8875  17.5594
# CH4_skew_CH4_w_ratio                                 6.5753   6.1076   5.8809
# pflow_mad_6h                                         6.1041   7.4734   7.4404
# CH4_w_mad_7D                                        20.3768  18.3656  18.1143
# CH4_area_roll_mean_3h                               18.5079  17.0341  16.8522
# CH4_area_lag_3                                      19.9095  16.0001  15.0767
# CH4_area_roll_mean_1h                               17.5999  17.5509  16.2347
# CH4_ht_lag_6                                        13.6827  17.0075  15.0896
# CH4_ht_robust_residual_7D                           13.0960  10.4730   9.4099
# CH4_ht_per_rank_7D                                   4.4762   4.8821   4.8609
# pflow_mad_24h                                        4.8219   5.2924   6.2884
# CH4_rt_robust_residual_7D                           16.1560  13.7204  17.0674
# CH4_ht_lag_72_robust_residual_7D                     9.2067   7.8400   7.8340
# CH4_skew_per_rank_7D                                 4.9571   4.8680   5.1770
# CH4_ht_residual_7D                                   7.8203   8.4854   8.0891
# CH4_area_lag_72_roll_median_24h                     17.3108  13.9881  17.6285
# CH4_area_lag_1                                      18.9765  15.2711  16.3953
# CH4_area_lag_6                                      14.5253  14.5609  14.0401
# CH4_area_roll_median_3h                             12.9545  12.4705  11.7628
# CH4_area_roll_mean_6h                               11.7327  10.9592  11.1152
# CH4_ht_lag_72_roll_median_24h                       11.9392  10.1255  10.7034
# CH4_area_lag_72_robust_residual_7D                   7.0799   6.1538   5.8365
# CH4_area_roll_median_1h                              9.6067  17.2210  15.0713
# CH4_rt_residual_6h                                  13.1430  10.3479   9.1842
# CH4_ht_lag_72_robust_residual_6h                     3.8352   3.8722   5.4637
# pflow_mad_3h                                         5.4628   6.6400   6.1104
# CH4_area_lag_72_robust_residual_6h                   4.7096   4.5960   4.6492
# CH4_area_lag_72_robust_residual_3D                   3.9090   5.5949   6.4056
# CH4_area_lag_72_robust_residual_24h                  3.6909   5.5562   5.3498
# CH4_area_lag_72_robust_residual_1h                   3.6785   5.4908   5.7744
# CH4_ht_lag_72_robust_residual_3h                     7.4777   6.7518   6.1745
# CH4_ht_lag_72_roll_median_6h                        10.4016  10.3885   8.9232
# CH4_ht_lag_72_robust_residual_3D                     5.8642   5.3044   4.6347
# CH4_ht_lag_72_robust_residual_1h                     5.4794   4.6116   5.1752
# CH4_area_lag_72_robust_residual_3h                   4.7109   6.8198   6.2758
# CH4_rt_robust_residual_3D                            9.5092   8.2093   7.7275
# CH4_ht_lag_72_robust_residual_24h                    7.6195   6.3895   5.9408
# CH4_ht_lag_72                                        6.3647   8.7025   7.6911
# CH4_ht_CH4_ht_lag_72_diff_cross                      9.9209   8.1854   7.5657
# CH4_rt_residual_3h                                  19.4241  13.9025  11.6222
# CH4_ht_diff_72                                       8.9332  10.4497   9.5566
# CH4_ht_lag_72_roll_median_3h                         7.5045   8.2996   9.3857
# CH4_ht_lag_72_roll_median_1h                         8.4023   8.7820   8.7233
# CH4_area_lag_72_roll_median_6h                      12.8397  15.7054  14.3796
# CH4_rt_robust_residual_24h                           6.3912   5.9251   5.3990
# CH4_end_time_CH4_start_time_diff_cross_roll_std_3h   9.3258  18.4980  18.4776
# CH4_area_lag_72_roll_median_3h                      12.3369  10.7582  11.0700
# CH4_area_lag_72                                     19.9218  15.2715  13.9664
# CH4_area_lag_72_roll_median_1h                      15.6387  12.4352  12.3797
# CH4_end_time_CH4_start_time_diff_cross_roll_std_1h  23.4849  21.0038  25.4133
# CH4_rt_robust_residual_3h                            6.0039   5.6499   6.3649
# CH4_rt_robust_residual_6h                            5.1482   6.4070   6.4179
# CH4_w_roll_std_1h                                   15.1119  14.4736  13.4742
# CH4_w_mad_6h                                        34.1112  34.0679  32.7061
# CH4_rt_residual_1h                                   7.5909   7.4738   7.3090
# CH4_rt_robust_residual_1h                            5.3911   5.9998   5.6554
# CH4_rt_diff_72                                       7.1112  14.5059  12.1560
# CH4_rt_mad_7D                                       26.5278  31.9936  29.5987
# CH4_rt_diff_6                                        6.8308   8.2276   7.6429
# CH4_rt_diff_3                                        8.8683   7.5600   8.0316
# CH4_rt_mad_3D                                       36.1291  30.5801  28.5148
# CH4_w_mad_3h                                         8.7270  21.2369  19.4724
# CH4_rt_diff_1                                        9.6589   7.2437   7.2570
# tmod                                                18.5687  16.4450  17.1324
# CH4_rt_mad_24h                                      18.1086  14.8068  17.4486
# CH4_rt_mad_6h                                       10.3859   9.4302   9.4345
# CH4_rt_mad_3h                                        6.5643   6.2798   7.4078
# CH4_ht_mad_1h                                       18.9191  17.3449  17.2782
# CH4_area_mad_1h                                     23.2311  24.8456  24.1479
# CH4_w_mad_1h                                        21.1549  22.4186  19.8155
# CH4_rt_mad_1h                                       18.2893  29.5954  27.7749
# pflow_mad_1h                                        52.1808  41.8044  53.3347

# %%
plot_data = cv_compare.loc[top50]

plt.figure(figsize=(8, 10))

sns.heatmap(
    plot_data,
    annot=True,
    fmt=".5f"
)

plt.xlabel("number pf Bags")
plt.ylabel("Feature")
plt.title("Feature Importance coefficient of variation (CV) vs Number of PU Bags")
plt.tight_layout()
plt.show()

plt.savefig("img/Fea_imp10_30__cv_compare.png")

# %% [markdown]
# ### Rank Compare

# %%
rank_compare = pd.concat({
    "10 bag": rank_10.set_index("Feature")["rank_mean"],
    "20 bag": rank_20.set_index("Feature")["rank_mean"],
    "30 bag": rank_30.set_index("Feature")["rank_mean"]
}, axis = 1)

rank_compare
# Out:
#                                                     10 bag  20 bag    30 bag
# Feature
# CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio         1.0    1.05    1.0667
# CH4_rt_to_last_air_ratio                               2.5    2.60    2.5333
# CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio     2.8    2.65    2.6667
# CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio       5.8    6.80    7.3667
# duration_rt_ratio                                      6.4    6.40    6.2000
# rt_position                                            6.9    7.40    6.6667
# CH4_ht_to_last_std_ratio                               7.2    7.05    7.0333
# CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio           8.0    7.70    7.4667
# CH4_w_residual_6h                                      8.8   10.55   10.9667
# CH4_end_time                                          10.3   10.05   10.1667
# CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio          10.3   10.05    9.9000
# CH4_rt_pflow_ratio                                    11.3   10.65   11.5333
# level_area_ratio                                      12.8   12.75   12.6000
# CH4_w_residual_3h                                     17.1   17.60   17.5333
# CH4_w_robust_residual_3h                              17.8   16.70   16.7333
# CH4_w_robust_residual_6h                              17.9   17.85   17.8000
# CH4_start_level_to_last_std_ratio                     19.3   21.75   21.5000
# CH4_area_residual_1h                                  19.9   19.85   19.8000
# CH4_area_robust_residual_1h                           20.0   19.10   19.6333
# CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio            21.5   20.80   21.0667
# CH4_area_to_last_std_ratio                            22.3   22.45   21.0667
# CH4_area_diff_1                                       23.0   22.60   22.9000
# CH4_ht_residual_1h                                    23.4   25.40   26.1667
# CH4_ht_pflow_ratio                                    25.2   24.60   24.5000
# CH4_w_residual_24h                                    25.4   25.60   25.4667
# CH4_start_time                                        27.1   27.30   27.3000
# CH4_ht_diff_1_CH4_ht_lag_1_per_change                 27.6   25.15   25.3333
# CH4_w_diff_1                                          27.7   27.25   26.6000
# CH4_w                                                 27.9   26.95   27.3000
# CH4_area_to_last_air_ratio                            27.9   29.30   29.5667
# CH4_w_diff_3                                          33.0   35.35   35.4667
# CH4_ht_diff_1                                         33.3   34.90   33.8000
# CH4_w_robust_residual_1h                              33.7   33.60   34.4000
# CH4_end_time_CH4_start_time_diff_cross                34.7   35.65   36.0333
# CH4_w_residual_1h                                     35.7   34.45   34.5000
# CH4_rt_to_last_std_ratio                              36.9   41.15   41.5333
# CH4_w_robust_residual_24h                             38.3   38.70   38.2000
# CH4_ht                                                38.8   38.05   38.1000
# CH4_w_diff_6                                          39.7   40.45   39.0667
# CH4_skew                                              40.1   39.25   39.6333
# CH4_ht_robust_residual_1h                             40.4   37.65   36.8667
# CH4_rt_roll_mean_3h                                   41.0   39.85   39.5333
# CH4_area_roll_std_24h                                 43.8   47.20   48.6333
# CH4_area_robust_residual_3h                           44.4   44.75   44.9333
# CH4_w_robust_residual_3D                              44.4   44.30   44.5000
# CH4_ht_robust_residual_3h                             45.4   49.80   49.5000
# is_air                                                47.4   47.85   47.9000
# CH4_area_residual_3h                                  49.1   47.40   47.8000
# is_std                                                49.8   48.75   48.9333
# CH4_rt_pflow_diff_cross                               50.3   48.15   47.8667
# CH4_end_level                                         51.0   51.80   52.2333
# CH4_area_roll_std_6h                                  52.2   46.95   47.4333
# CH4_end_time_CH4_start_time_diff_cross_roll_std...    55.3   56.90   58.3667
# CH4_ht_roll_mean_1h                                   57.5   56.40   57.8333
# last_air_CH4_start_level                              58.5   58.75   58.6667
# CH4_w_CH4_end_time_CH4_start_time_diff_cross_ratio    59.2   57.70   57.0000
# CH4_ht_roll_std_24h                                   61.1   66.35   67.0667
# CH4_w_roll_mean_3h                                    61.6   65.10   69.4333
# CH4_ht_roll_std_3h                                    62.0   64.50   70.0333
# CH4_ht_lag_1                                          63.6   63.15   70.6333
# CH4_ht_roll_std_6h                                    63.6   64.10   59.7333
# CH4_start_level                                       65.3   64.20   62.7000
# CH4_rt_roll_mean_1h                                   65.5   65.40   65.5667
# CH4_w_3h_zcore_res_gen                                66.3   67.70   69.8000
# CH4_area_roll_std_3h                                  66.8   69.35   70.0333
# CH4_ht_roll_mean_6h                                   67.9   68.20   67.9667
# CH4_ht_residual_3h                                    69.0   64.75   65.2667
# CH4_w_roll_std_6h                                     69.5   81.10   81.8000
# CH4_w_relative_per_7h                                 70.8   67.70   68.0000
# CH4_ht_relative_per_7h                                70.9   70.60   70.4333
# CH4_w_robust_residual_7D                              73.6   67.80   70.6000
# CH4_area_residual_6h                                  73.9   75.10   73.8667
# CH4_w_roll_std_24h                                    74.8   71.95   69.4667
# CH4_ht_residual_6h                                    79.2   74.90   75.6667
# CH4_ht_roll_std_7D                                    79.4   84.60   83.7667
# CH4_area_diff_3                                       80.1   80.05   80.6333
# CH4_w_residual_3D                                     80.9   73.35   71.3667
# CH4_ht_to_last_air_ratio                              81.3   81.40   80.5000
# CH4_area_robust_residual_6h                           83.0   84.95   84.3333
# CH4_end_time_CH4_start_time_diff_cross_roll_std_7D    86.2   85.85   85.1667
# CH4_rt_roll_mean_7D                                   88.7   87.20   87.0667
# CH4_ht_diff_3                                         88.9   88.50   84.3667
# last_std_CH4_area                                     90.1   89.65   91.1333
# CH4_rt_roll_mean_3D                                   90.1   88.50   89.4333
# last_std_CH4_ht                                       90.2   91.45   92.8667
# CH4_w_roll_std_7D                                     91.0   93.55   93.9000
# CH4_w_residual_7D                                     91.2   85.80   85.0667
# CH4_rt_roll_mean_24h                                  91.8   91.60   92.3000
# CH4_area_roll_std_3D                                  93.4   95.65   95.1333
# CH4_area_roll_std_7D                                  93.7   89.75   88.6333
# CH4_rt_roll_median_3D                                 95.0   99.75   99.0667
# CH4_w_relative_per_2h                                 95.6   97.30   98.2667
# CH4_end_time_CH4_start_time_diff_cross_roll_std_3D    97.2   99.30   99.5000
# CH4_start_level_CH4_end_level_ratio                   99.4  102.60  103.4333
# CH4_ht_roll_std_3D                                   100.0   97.45   99.1333
# CH4_ht_robust_residual_6h                            102.5   97.75   97.8333
# CH4_area_lag_72_roll_median_7D                       103.2  103.20  106.2000
# CH4_area_roll_median_7D                              104.0  104.00  104.7333
# CH4_ht_mad_6h                                        104.5  109.25  108.7000
# CH4_rt_roll_mean_6h                                  105.6  107.85  111.5000
# baseline_slope                                       107.2  103.85  103.1667
# CH4_w_roll_std_3D                                    108.5  105.40  103.7667
# CH4_ht_mad_3D                                        108.8  116.35  116.1667
# pflow_roll_median_7D                                 109.7  112.10  113.0333
# CH4_w_roll_mean_24h                                  109.8  110.40  108.8000
# CH4_end_time_CH4_start_time_diff_cross_roll_std_6h   110.5  100.85   97.9333
# CH4_end_level_CH4_start_level_diff_cross             110.5  109.80  109.3667
# CH4_w_roll_mean_3D                                   113.8  114.85  112.7000
# CH4_w_roll_mean_6h                                   113.8  115.05  112.8000
# CH4_ht_roll_median_3h                                117.1  104.90  111.0667
# CH4_area_mad_6h                                      117.8  114.90  113.7667
# CH4_rt_roll_median_7D                                119.3  119.25  119.6000
# CH4_ht_CH4_w_ratio                                   119.5  127.40  130.6333
# pflow_roll_median_3D                                 120.2  122.10  125.7333
# CH4_ht_mad_24h                                       120.3  119.20  120.9000
# CH4_w_roll_median_3D                                 120.7  126.15  123.0333
# last_std_CH4_start_level                             121.7  118.45  118.3333
# CH4_ht_residual_24h                                  124.9  133.15  137.7667
# CH4_ht_CH4_area_ratio                                125.5  125.45  121.9333
# CH4_area_mad_3h                                      125.6  129.55  126.5000
# CH4_w_roll_mean_7D                                   126.9  127.00  124.3667
# CH4_ht_lag_72_roll_median_7D                         127.1  122.80  123.1333
# CH4_area_mad_3D                                      127.8  133.00  135.3333
# CH4_ht_roll_median_7D                                128.2  129.30  128.8333
# CH4_start_level_to_last_air_ratio                    128.5  123.90  125.5667
# CH4_ht_relative_per_2h                               128.9  130.55  129.1667
# CH4_w_roll_median_7D                                 132.7  130.75  129.3333
# CH4_ht_mad_7D                                        133.2  131.15  132.9667
# CH4_area_mad_24h                                     133.9  132.70  131.0667
# CH4_w_roll_mean_1h                                   134.2  148.10  155.4000
# pflow_lag_72                                         134.3  136.00  138.2667
# CH4_w_diff_72                                        134.8  148.90  144.8667
# pflow_robust_residual_6h                             136.2  137.35  136.5667
# last_std_CH4_rt                                      136.8  139.25  137.1000
# CH4_w_roll_median_24h                                137.1  130.55  127.5333
# CH4_area_roll_std_1h                                 137.5  138.10  139.0333
# CH4_area_residual_24h                                137.6  150.25  156.3333
# CH4_w_roll_median_3h                                 137.6  135.60  138.7667
# CH4_area_residual_7D                                 138.0  141.45  123.3000
# CH4_w_roll_median_6h                                 140.1  130.15  131.1333
# CH4_ht_diff_6                                        143.9  142.95  137.7333
# CH4_rt_residual_7D                                   144.5  137.20  138.7333
# CH4_area_roll_median_3D                              145.4  146.65  142.6000
# CH4_ht_roll_median_3D                                146.0  150.40  152.5000
# CH4_area_roll_mean_7D                                146.3  142.75  143.7000
# CH4_area                                             146.9  122.15  122.3333
# CH4_w_roll_median_1h                                 147.4  152.65  152.8667
# CH4_rt_roll_median_24h                               148.1  143.25  139.3333
# CH4_ht_mad_3h                                        148.6  144.25  143.4333
# pflow_roll_median_24h                                148.8  149.55  150.1000
# CH4_ht_roll_mean_7D                                  149.9  152.05  151.1000
# pflow_robust_residual_3h                             150.3  151.55  151.2000
# CH4_w_lag_1                                          151.0  154.90  161.2000
# CH4_area_mad_7D                                      151.5  154.30  153.6333
# CH4_w_lag_3                                          152.4  156.00  153.5333
# CH4_ht_robust_residual_24h                           153.9  155.30  163.1667
# CH4_rt_lag_1                                         156.4  159.25  154.0667
# CH4_area_lag_72_roll_median_3D                       156.8  160.90  164.4000
# CH4_w_mad_24h                                        157.3  153.65  152.1333
# CH4_ht_roll_std_1h                                   157.8  160.45  160.0000
# CH4_area_pflow_ratio                                 158.0  156.10  157.9667
# CH4_area_diff_6                                      159.0  151.00  147.0333
# CH4_w_lag_6                                          159.8  154.85  158.6333
# pflow_roll_median_6h                                 160.7  164.35  166.4667
# CH4_w_roll_std_3h                                    161.8  159.95  166.8667
# pflow_robust_residual_24h                            161.8  165.45  164.8333
# CH4_rt_roll_median_3h                                162.1  163.60  165.9000
# pflow_lag_6                                          162.7  162.90  165.2333
# CH4_ht_roll_mean_3h                                  162.9  166.05  163.8333
# pflow_roll_median_3h                                 166.0  172.55  173.5667
# CH4_ht_lag_72_roll_median_3D                         166.6  169.55  171.6667
# pflow_robust_residual_7D                             167.9  166.55  165.5000
# CH4_area_robust_residual_24h                         168.4  171.15  168.6000
# CH4_w_lag_72                                         169.9  172.15  174.1667
# CH4_w_mad_3D                                         170.7  166.05  162.3000
# CH4_rt_roll_median_6h                                170.9  165.25  163.7333
# pflow_mad_7D                                         172.1  169.20  168.0333
# CH4_area_diff_72                                     174.1  167.60  165.1667
# pflow                                                174.4  173.05  170.3333
# pflow_roll_median_1h                                 175.7  170.35  173.1667
# pflow_lag_1                                          178.2  173.25  174.4000
# pflow_robust_residual_1h                             178.5  180.45  180.1667
# CH4_ht_robust_residual_3D                            178.8  175.15  173.6000
# pflow_lag_3                                          179.2  174.95  174.4667
# CH4_w_per_rank_7D                                    181.1  180.25  181.4000
# CH4_ht_roll_mean_3D                                  181.5  185.40  185.4000
# last_air_CH4_rt                                      182.9  187.00  182.3000
# last_air_CH4_ht                                      183.0  187.10  186.2333
# CH4_area_roll_mean_3D                                183.3  178.50  175.3667
# pflow_mad_3D                                         186.8  184.70  186.0667
# CH4_rt                                               186.8  188.55  186.5333
# CH4_ht_roll_mean_24h                                 189.9  188.15  185.3000
# CH4_rt_roll_median_1h                                190.6  189.65  191.0000
# CH4_area_residual_3D                                 191.5  189.95  195.8333
# CH4_rt_lag_3                                         192.5  196.05  195.3667
# pflow_robust_residual_3D                             193.3  192.75  193.5333
# CH4_area_robust_residual_3D                          196.1  200.35  198.3333
# CH4_ht_roll_median_24h                               196.3  197.60  198.0333
# CH4_rt_residual_3D                                   197.5  194.60  198.1667
# CH4_area_roll_mean_24h                               201.0  203.50  202.8667
# CH4_rt_lag_6                                         201.6  197.70  200.9333
# last_air_CH4_area                                    201.9  198.95  191.5667
# CH4_area_robust_residual_7D                          202.2  203.65  201.2667
# CH4_rt_lag_72                                        203.7  200.15  198.7333
# CH4_ht_roll_median_6h                                206.2  201.90  200.7333
# CH4_area_roll_median_24h                             206.7  206.10  204.2667
# CH4_ht_roll_median_1h                                207.4  207.70  201.6000
# CH4_skew_CH4_w_ratio                                 208.5  210.55  210.6000
# CH4_rt_residual_24h                                  208.6  204.30  207.3667
# pflow_mad_6h                                         209.6  216.50  213.3333
# CH4_area_CH4_area_lag_72_diff_cross                  209.7  221.80  227.6667
# CH4_ht_lag_3                                         209.7  210.95  211.3667
# CH4_ht_residual_3D                                   210.3  218.90  220.4667
# CH4_area_roll_median_6h                              211.7  203.95  201.3667
# CH4_w_mad_7D                                         213.1  213.25  209.2000
# CH4_area_roll_mean_3h                                216.1  215.55  214.6667
# CH4_ht_per_rank_7D                                   217.5  216.00  216.4000
# pflow_mad_24h                                        218.4  218.25  220.6000
# CH4_ht_lag_6                                         218.7  208.80  208.9333
# CH4_area_roll_mean_1h                                219.0  217.00  216.8000
# CH4_ht_robust_residual_7D                            219.2  223.30  222.1333
# CH4_skew_per_rank_7D                                 219.6  219.55  221.7667
# CH4_ht_residual_7D                                   220.2  222.05  218.9667
# CH4_ht_lag_72_robust_residual_7D                     221.0  221.30  222.9667
# CH4_area_lag_3                                       221.1  216.90  221.8333
# CH4_rt_robust_residual_7D                            221.8  224.70  220.5000
# CH4_area_lag_1                                       222.3  220.90  211.9333
# CH4_area_lag_6                                       222.9  223.60  223.8667
# CH4_area_lag_72_roll_median_24h                      224.6  225.50  225.8000
# CH4_area_roll_median_3h                              225.0  221.50  217.8333
# CH4_area_roll_mean_6h                                225.2  228.30  226.8000
# CH4_ht_lag_72_roll_median_24h                        226.8  223.70  220.5667
# CH4_area_lag_72_robust_residual_7D                   227.9  229.15  230.5333
# CH4_area_roll_median_1h                              229.1  218.30  219.6000
# CH4_ht_lag_72_robust_residual_6h                     231.1  230.65  233.7667
# CH4_rt_residual_6h                                   231.2  235.05  235.4000
# pflow_mad_3h                                         231.5  235.60  236.7667
# CH4_area_lag_72_robust_residual_6h                   234.2  235.10  235.4667
# CH4_ht_lag_72_robust_residual_3h                     234.5  235.50  236.5000
# CH4_area_lag_72_robust_residual_3D                   234.5  239.00  237.5667
# CH4_area_lag_72_robust_residual_24h                  235.2  239.60  237.9000
# CH4_ht_lag_72_roll_median_6h                         235.7  241.60  243.1333
# CH4_area_lag_72_robust_residual_1h                   235.7  236.55  234.9667
# CH4_ht_lag_72_robust_residual_3D                     238.6  238.85  239.9000
# CH4_area_lag_72_robust_residual_3h                   239.8  237.20  236.7333
# CH4_ht_lag_72_robust_residual_24h                    240.1  241.85  241.3000
# CH4_ht_lag_72_robust_residual_1h                     240.2  240.50  239.9333
# CH4_rt_robust_residual_3D                            241.2  237.30  236.3667
# CH4_ht_CH4_ht_lag_72_diff_cross                      245.7  245.10  246.1000
# CH4_ht_lag_72                                        247.4  247.60  248.0333
# CH4_ht_diff_72                                       247.6  246.35  247.6667
# CH4_rt_residual_3h                                   248.4  249.00  249.1000
# CH4_ht_lag_72_roll_median_3h                         249.5  245.75  245.8667
# CH4_area_lag_72                                      249.6  253.55  252.9333
# CH4_area_lag_72_roll_median_6h                       249.6  245.10  249.3000
# CH4_ht_lag_72_roll_median_1h                         249.8  250.65  250.2667
# CH4_area_lag_72_roll_median_1h                       249.9  255.25  254.4667
# CH4_end_time_CH4_start_time_diff_cross_roll_std_1h   250.2  254.00  255.0000
# CH4_area_lag_72_roll_median_3h                       251.9  252.35  254.3333
# CH4_end_time_CH4_start_time_diff_cross_roll_std_3h   252.4  244.65  246.7667
# CH4_rt_robust_residual_24h                           252.7  250.65  251.2333
# CH4_w_mad_6h                                         252.8  250.30  254.6000
# CH4_rt_robust_residual_3h                            259.3  259.50  259.0000
# CH4_w_roll_std_1h                                    261.0  258.90  258.4333
# CH4_rt_robust_residual_6h                            261.4  261.75  261.3333
# CH4_rt_mad_7D                                        265.4  261.05  260.9333
# CH4_rt_residual_1h                                   265.6  266.20  265.9000
# CH4_rt_robust_residual_1h                            266.5  266.50  266.2000
# CH4_rt_diff_72                                       266.7  264.50  265.2333
# CH4_rt_mad_3D                                        269.2  270.15  270.9333
# CH4_rt_diff_6                                        270.2  270.05  269.9333
# CH4_rt_diff_3                                        270.8  270.95  271.0667
# CH4_w_mad_3h                                         272.8  271.70  271.5000
# CH4_rt_diff_1                                        273.9  274.35  274.3000
# tmod                                                 275.5  275.40  275.6667
# CH4_rt_mad_24h                                       275.7  275.25  275.2667
# CH4_rt_mad_6h                                        276.4  276.70  276.6000
# CH4_rt_mad_3h                                        276.8  277.00  276.9000
# CH4_ht_mad_1h                                        279.2  279.15  279.1333
# CH4_area_mad_1h                                      280.1  280.10  280.1000
# CH4_w_mad_1h                                         280.7  280.80  280.8333
# CH4_rt_mad_1h                                        282.3  282.20  282.2000
# pflow_mad_1h                                         282.7  282.75  282.7333

# %%
plot_data = rank_compare.loc[top50]

plt.figure(figsize=(8, 10))

sns.heatmap(
    plot_data,
    annot=True,
    fmt=".1f"
)

plt.xlabel("number pf Bags")
plt.ylabel("Feature")
plt.title("Feature Importance Rank vs Number of PU Bags")
plt.tight_layout()
plt.show()

plt.savefig("img/Fea_imp5_30__rank_compare.png")

# %% [markdown]
# #### Compare them together

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# rank 的 top3 是基於mean feature importance 在30 bags
# 所以會看到6.7 在7.1上面

# %%
# top 30' feature
top50.tolist()
# Out:
# ['CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio',
#  'CH4_rt_to_last_air_ratio',
#  'CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio',
#  'duration_rt_ratio',
#  'CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio',
#  'rt_position',
#  'CH4_ht_to_last_std_ratio',
#  'CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio',
#  'CH4_w_residual_6h',
#  'CH4_end_time',
#  'CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio',
#  'CH4_rt_pflow_ratio',
#  'level_area_ratio',
#  'CH4_w_robust_residual_3h',
#  'CH4_w_residual_3h',
#  'CH4_w_robust_residual_6h',
#  'CH4_area_robust_residual_1h',
#  'CH4_area_residual_1h',
#  'CH4_area_to_last_std_ratio',
#  'CH4_start_level_to_last_std_ratio',
#  'CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio',
#  'CH4_area_diff_1',
#  'CH4_ht_pflow_ratio',
#  'CH4_w_residual_24h',
#  'CH4_ht_diff_1_CH4_ht_lag_1_per_change',
#  'CH4_w_diff_1',
#  'CH4_ht_residual_1h',
#  'CH4_start_time',
#  'CH4_w',
#  'CH4_area_to_last_air_ratio',
#  'CH4_ht_diff_1',
#  'CH4_w_robust_residual_1h',
#  'CH4_w_residual_1h',
#  'CH4_w_diff_3',
#  'CH4_end_time_CH4_start_time_diff_cross',
#  'CH4_ht_robust_residual_1h',
#  'CH4_w_robust_residual_24h',
#  'CH4_w_diff_6',
#  'CH4_ht',
#  'CH4_rt_to_last_std_ratio',
#  'CH4_skew',
#  'CH4_rt_roll_mean_3h',
#  'CH4_rt_pflow_diff_cross',
#  'CH4_area_robust_residual_3h',
#  'CH4_w_robust_residual_3D',
#  'CH4_area_roll_std_6h',
#  'CH4_area_roll_std_24h',
#  'is_air',
#  'CH4_area_residual_3h',
#  'CH4_ht_robust_residual_3h']

# %%
df_filter = pd.DataFrame({
    'importance':importance_compare['30 bag'],
    'cv': cv_compare['30 bag'],
    'rank':rank_compare['30 bag']
}).reset_index()


rule1_mask = ~((df_filter['rank'] > 50) & (df_filter['importance'] < 0.01))

rule2_mask = ~((df_filter['cv'] > 20.0) & (df_filter['rank'] > 50))

df_selected = df_filter[rule1_mask & rule2_mask].sort_values("rank")
candidate_features = df_selected['Feature'].head(50).tolist()

#print(f"Save faetures: {len(candidate_features)}")
#print("Top5", candidate_features[:5])

# %%
candidate_features
# Out:
# ['CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio',
#  'CH4_rt_to_last_air_ratio',
#  'CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio',
#  'duration_rt_ratio',
#  'rt_position',
#  'CH4_ht_to_last_std_ratio',
#  'CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio',
#  'CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio',
#  'CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio',
#  'CH4_end_time',
#  'CH4_w_residual_6h',
#  'CH4_rt_pflow_ratio',
#  'level_area_ratio',
#  'CH4_w_robust_residual_3h',
#  'CH4_w_residual_3h',
#  'CH4_w_robust_residual_6h',
#  'CH4_area_robust_residual_1h',
#  'CH4_area_residual_1h',
#  'CH4_area_to_last_std_ratio',
#  'CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio',
#  'CH4_start_level_to_last_std_ratio',
#  'CH4_area_diff_1',
#  'CH4_ht_pflow_ratio',
#  'CH4_ht_diff_1_CH4_ht_lag_1_per_change',
#  'CH4_w_residual_24h',
#  'CH4_ht_residual_1h',
#  'CH4_w_diff_1',
#  'CH4_w',
#  'CH4_start_time',
#  'CH4_area_to_last_air_ratio',
#  'CH4_ht_diff_1',
#  'CH4_w_robust_residual_1h',
#  'CH4_w_residual_1h',
#  'CH4_w_diff_3',
#  'CH4_end_time_CH4_start_time_diff_cross',
#  'CH4_ht_robust_residual_1h',
#  'CH4_ht',
#  'CH4_w_robust_residual_24h',
#  'CH4_w_diff_6',
#  'CH4_rt_roll_mean_3h',
#  'CH4_skew',
#  'CH4_rt_to_last_std_ratio',
#  'CH4_w_robust_residual_3D',
#  'CH4_area_robust_residual_3h',
#  'CH4_area_roll_std_6h',
#  'CH4_area_residual_3h',
#  'CH4_rt_pflow_diff_cross',
#  'is_air',
#  'CH4_area_roll_std_24h',
#  'is_std']

# %%
len(candidate_features)
# Out:
# 50

# %%
from sklearn.metrics import average_precision_score
val_split_idx = int(len(X_train_final)*0.8)
X_tr = X_train_final.iloc[:val_split_idx]
y_tr = y_train.iloc[:val_split_idx]

X_val = X_train_final.iloc[val_split_idx:]
y_val = y_train.iloc[val_split_idx:]

k_candidates = np.arange(10, 60, 10)
k_list = [k for k in k_candidates if k <= len(candidate_features)]


val_prc_scores = []

print("=== Start ===")

for k in k_list:
    sub_features = candidate_features[:k]
    models, _, _ = bagging_rf(10, X_tr[sub_features], y_tr)

    val_preds = np.mean([m.predict_proba(X_val[sub_features])[:, 1] for m in models], axis=0)
    prc_auc= average_precision_score(y_val, val_preds)
    val_prc_scores.append(prc_auc)

    print(f"TOP K = {k:2d} features | validation (PR-AUC): {prc_auc:.4f}")

best_idx = np.argmax(val_prc_scores)
best_k = k_list[best_idx]

best_features = candidate_features[:best_k]

plt.figure(figsize=(8,5))
plt.plot(k_list, val_prc_scores, 'o-', color='blue', label='PR-AUC Score')


plt.annotate(
    f"Optimal K = {best_k}\nPR-AUC = {val_prc_scores[best_idx]:.4f}",
    xy = (best_k, val_prc_scores[best_idx]),
    xytext=(best_k, val_prc_scores[best_idx] - 0.02),
    arrowprops=dict(facecolor='black')
)


plt.title('PU-Bagging Feature Selection Learning Curve (PRC / PR-AUC)')
plt.xlabel("Number of Selecte Top Features (K)")
plt.ylabel("validation PR-AUC Score")
plt.xticks(k_list)
plt.grid(True, linestyle='--')
plt.show()
print(f'Final features and number:', best_k, "\n", best_features)
# Out:
# === Start ===
# Number of Bag: 10
# Positive: 18296
# Unlabeled: 479128
#
#  PU training data, Bag 1/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 2/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 3/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 4/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 5/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 6/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 7/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 8/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 9/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 10/10 Positive = 18296, Unlabeled = 18296
# TOP K = 10 features | validation (PR-AUC): 0.4976
# Number of Bag: 10
# Positive: 18296
# Unlabeled: 479128
#
#  PU training data, Bag 1/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 2/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 3/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 4/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 5/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 6/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 7/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 8/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 9/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 10/10 Positive = 18296, Unlabeled = 18296
# TOP K = 20 features | validation (PR-AUC): 0.6550
# Number of Bag: 10
# Positive: 18296
# Unlabeled: 479128
#
#  PU training data, Bag 1/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 2/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 3/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 4/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 5/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 6/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 7/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 8/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 9/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 10/10 Positive = 18296, Unlabeled = 18296
# TOP K = 30 features | validation (PR-AUC): 0.6604
# Number of Bag: 10
# Positive: 18296
# Unlabeled: 479128
#
#  PU training data, Bag 1/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 2/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 3/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 4/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 5/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 6/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 7/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 8/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 9/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 10/10 Positive = 18296, Unlabeled = 18296
# TOP K = 40 features | validation (PR-AUC): 0.6516
# Number of Bag: 10
# Positive: 18296
# Unlabeled: 479128
#
#  PU training data, Bag 1/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 2/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 3/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 4/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 5/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 6/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 7/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 8/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 9/10 Positive = 18296, Unlabeled = 18296
#
#  PU training data, Bag 10/10 Positive = 18296, Unlabeled = 18296
# TOP K = 50 features | validation (PR-AUC): 0.6694
# Final features and number: 50
#  ['CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio', 'CH4_rt_to_last_air_ratio', 'CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio', 'duration_rt_ratio', 'rt_position', 'CH4_ht_to_last_std_ratio', 'CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio', 'CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio', 'CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio', 'CH4_end_time', 'CH4_w_residual_6h', 'CH4_rt_pflow_ratio', 'level_area_ratio', 'CH4_w_robust_residual_3h', 'CH4_w_residual_3h', 'CH4_w_robust_residual_6h', 'CH4_area_robust_residual_1h', 'CH4_area_residual_1h', 'CH4_area_to_last_std_ratio', 'CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio', 'CH4_start_level_to_last_std_ratio', 'CH4_area_diff_1', 'CH4_ht_pflow_ratio', 'CH4_ht_diff_1_CH4_ht_lag_1_per_change', 'CH4_w_residual_24h', 'CH4_ht_residual_1h', 'CH4_w_diff_1', 'CH4_w', 'CH4_start_time', 'CH4_area_to_last_air_ratio', 'CH4_ht_diff_1', 'CH4_w_robust_residual_1h', 'CH4_w_residual_1h', 'CH4_w_diff_3', 'CH4_end_time_CH4_start_time_diff_cross', 'CH4_ht_robust_residual_1h', 'CH4_ht', 'CH4_w_robust_residual_24h', 'CH4_w_diff_6', 'CH4_rt_roll_mean_3h', 'CH4_skew', 'CH4_rt_to_last_std_ratio', 'CH4_w_robust_residual_3D', 'CH4_area_robust_residual_3h', 'CH4_area_roll_std_6h', 'CH4_area_residual_3h', 'CH4_rt_pflow_diff_cross', 'is_air', 'CH4_area_roll_std_24h', 'is_std']

# %%
best_features[:30]
# Out:
# ['CH4_ht_roll_std_24h_CH4_ht_roll_mean_24h_ratio',
#  'CH4_rt_to_last_air_ratio',
#  'CH4_area_roll_std_24h_CH4_area_roll_mean_24h_ratio',
#  'duration_rt_ratio',
#  'rt_position',
#  'CH4_ht_to_last_std_ratio',
#  'CH4_area_roll_std_3h_CH4_area_roll_mean_3h_ratio',
#  'CH4_w_roll_std_24h_CH4_w_roll_mean_24h_ratio',
#  'CH4_ht_roll_std_3h_CH4_ht_roll_mean_3h_ratio',
#  'CH4_end_time',
#  'CH4_w_residual_6h',
#  'CH4_rt_pflow_ratio',
#  'level_area_ratio',
#  'CH4_w_robust_residual_3h',
#  'CH4_w_residual_3h',
#  'CH4_w_robust_residual_6h',
#  'CH4_area_robust_residual_1h',
#  'CH4_area_residual_1h',
#  'CH4_area_to_last_std_ratio',
#  'CH4_w_roll_std_3h_CH4_w_roll_mean_3h_ratio',
#  'CH4_start_level_to_last_std_ratio',
#  'CH4_area_diff_1',
#  'CH4_ht_pflow_ratio',
#  'CH4_ht_diff_1_CH4_ht_lag_1_per_change',
#  'CH4_w_residual_24h',
#  'CH4_ht_residual_1h',
#  'CH4_w_diff_1',
#  'CH4_w',
#  'CH4_start_time',
#  'CH4_area_to_last_air_ratio']

# %% [markdown]
# ==================================

# %% [markdown]
# =============
